# %% [markdown]
# # Basic Stats

# %%
# Raw tweets from streaming: /data/muntean/food-tweets
# Wordcount per day and whole (4-grams): /home/muntean/food-wordcount
import os
import sys
from collections import defaultdict
os.chdir("/Users/muntean/Documents/workspace/food101/")
from twitter.Tweet import Tweet

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Simple counts

# %%
tweetsAsDict = Tweet.getTweetAsDictionary("/Users/muntean/food-tweets/")

countTweets = 0
countCoords = 0
countPlace = 0
countUserLocation = 0
countImage = 0
countMedia =0 
for tweet, fileName in tweetsAsDict:
    if tweet["coordinates"] is not None:
        countCoords +=1
    if tweet["place"] is not None:
        countPlace +=1
    if tweet['user']['location'] is not None:
        countUserLocation +=1
    # we have two situations: either media is attached to the tweet or we have a link to instagram
    if "media" in tweet["entities"]:
        countMedia +=1
        foundMedia = tweet["entities"]["media"]
        # the type can be photo, video ...
        if foundMedia[0]["type"] == "photo":
            countImage += 1
    countTweets +=1

# %% [markdown]
# ### Intersections with tweets attributes

# %%
def getLocationData(tweet):
    """
    These can always have None values; e.g no coordinates, no city, no user location
    :param tweet:
    :return:
    """
    if tweet["coordinates"] is not None:
        tweet_coords = tweet['coordinates']['coordinates']  # returns a list [longitude, latitude]
    else:
        tweet_coords = None

    if tweet["place"] is not None:
        if tweet["place"]["place_type"] == "city":
            tweet_place_city = tweet["place"]["name"]  # if place type == city
            tweet_place_country = tweet["place"]["country"]
            tweet_place_country_code = tweet["place"]["country_code"]
        else:
            tweet_place_city = None
            tweet_place_country = tweet["place"]["country"]
            tweet_place_country_code = tweet["place"]["country_code"]
    else:
        tweet_place_city = None
        tweet_place_country = None
        tweet_place_country_code = None

    user_location = tweet['user']['location']

    return tweet_coords, tweet_place_city, tweet_place_country, tweet_place_country_code, user_location

# %%
tweetsAsDict = Tweet.getTweetAsDictionary("/Users/muntean/food-tweets")

dictCoords = defaultdict()
dictPlace = defaultdict()
dictUserLocation = defaultdict()
dictImage = defaultdict()

for tweet, fileName in tweetsAsDict:
    tweet_coords, tweet_place_city, tweet_place_country, tweet_place_country_code, user_location = getLocationData(tweet)
    if tweet_coords is not None:
        dictCoords[tweet["id_str"]] = tweet_coords
    if tweet_place_country_code is not None:
        dictPlace[tweet["id_str"]] = tweet_place_country # or country code or even city but may be less
    if user_location is not None:
        dictUserLocation[tweet["id_str"]] = user_location 
    if "media" in tweet["entities"]:
        foundMedia = tweet["entities"]["media"]
        dictImage[tweet["id_str"]] = foundMedia[0]["media_url"]

# %% [markdown]
# ## Atributes

# %% [markdown]
# ### 1. How many tweets in total?

# %%
# Food related tweets (filtered on relevant kw matching #food): 
print "Total Tweets: ", countTweets
# Out:
# Total Tweets:  69808

# %% [markdown]
# ### 2. How many tweets with Place or GEO? How many with valid user location?

# %%
# Tweets with Place, Geo and User location
print "Tweets with Coords: ", countCoords
print "Tweets with Place: ", countPlace
print "Tweets with User Location: ", countUserLocation
# Out:
# Tweets with Coords:  4801
# Tweets with Place:  6242
# Tweets with User Location:  49621

# %% [markdown]
# ### 3. How many tweets with image?

# %%
# Tweets with images or other media
print "Tweets with Image: ", countImage, " all media: ", countMedia
# Out:
# Tweets with Image:  18234  all media:  18234

# %% [markdown]
# ### 4. How many with combinations of all of the above?

# %%
# How many with coords and images
a = set(dictCoords.keys()).intersection(dictImage.keys())
print len(a)
# How many with Country code and images
b = set(dictPlace.keys()).intersection(dictImage.keys())
print len(b)
# How many with user location and images
c = set(dictUserLocation.keys()).intersection(dictImage.keys())
print len(c)


# print dictCoords["673842284794765312"]
# print dictPlace["673842284794765312"]
# print dictImage["673842284794765312"]
# Out:
# 52
# 643
# 11961

# %% [markdown]
# ## Distribution by countries

# %%
reversed_dictPlace = defaultdict(list)
for key,value in dictPlace.iteritems():
    reversed_dictPlace[value].append(key)
print "Total countries", len(reversed_dictPlace) 

#order dict per popularity
for k in sorted(reversed_dictPlace, key=lambda k: len(reversed_dictPlace[k]), reverse=True):
        print k, len(reversed_dictPlace[k])
# Out:
# Total countries 194
# United States 2282
# United Kingdom 523
# 日本 302
# Republic of the Philippines 262
# Italia 244
# Canada 243
# Indonesia 183
# Malaysia 148
# España 132
# México 122
# Australia 117
# India 114
# Thailand 83
# France 79
# Brasil 78
# Japan 69
# Argentina 62
# Deutschland 50
# Singapore 48
# Ireland 48
# Mexico 46
# South Africa 45
# Italy 42
# Spain 40
# Türkiye 34
# United Arab Emirates 34
# Chile 33
# Germany 30
# Colombia 28
# The Netherlands 23
# Brazil 23
# Vietnam 22
# Brunei 21
# Peru 19
# Estados Unidos 18
# ประเทศไทย 18
# Republic of Korea 18
# Hong Kong 17
# Nederland 15
# Sverige 15
# 台灣 15
# People's Republic of China 15
# New Zealand 13
# Pakistan 13
# Taiwan 13
# 中华人民共和国 13
# Portugal 10
# Ecuador 10
# Venezuela 10
# Polska 9
# Österreich 9
# Francia 8
# 대한민국 8
# Turkey 8
# Belgium 8
# Россия 8
# Sri Lanka 8
# Reino Unido 7
# Costa Rica 7
# Kingdom of Saudi Arabia 7
# Greece 7
# België 7
# Regno Unito 6
# Bahrain 6
# Kenya 6
# Sweden 6
# Espanya 6
# Republic of Slovenia 6
# Suomi 6
# Poland 6
# Etats-Unis 6
# Tanzania 5
# Republic of Serbia 5
# Dominican Republic 5
# Bulgaria 5
# Nigeria 5
# Denmark 5
# Uruguay 5
# Lebanon 5
# Panamá 5
# Lithuania 4
# Cambodia 4
# भारत 4
# Bangladesh 4
# Stati Uniti 4
# 香港 4
# Austria 4
# Belgique 4
# Nepal 4
# Hungary 4
# Republic of Croatia 3
# Guatemala 3
# Finland 3
# Việt Nam 3
# Canadá 3
# Tailandia 3
# Russia 3
# Switzerland 3
# Estonia 3
# Беларусь 3
# Ελλάς 3
# Maldives 2
# Paraguay 2
# Jamaica 2
# Allemagne 2
# Suisse 2
# Singapur 2
# مصر 2
# Magyarország 2
# Новая Зеландия 2
# Romania 2
# Albania 2
# Morocco 2
# Bahamas 2
# El Salvador 2
# Italien 2
# Vereinigtes Königreich 2
# Malta 2
# България 2
# Qatar 2
# Lao People's Democratic Republic 2
# Iceland 2
# Zambia 2
# Vereinigte Staaten 2
# Česká republika 2
# Andorra 2
# Trinidad and Tobago 2
# Latvia 2
# Myanmar 2
# Curaçao 2
# Irlanda 1
# Taïwan 1
# Aruba 1
# Cameroon 1
# La Réunion 1
# Emirati Arabi Uniti 1
# Paesi Bassi 1
# Panama 1
# Royaume du Maroc 1
# République populaire de Chine 1
# Monaco 1
# Republika ng Pilipinas 1
# Украина 1
# Guam 1
# Madagascar 1
# Polen 1
# Saint Lucia 1
# Luxembourg 1
# Grecia 1
# الامارات العربية المتحدة 1
# Ísland 1
# Armenia 1
# Schweiz 1
# Ukraine 1
# Ghana 1
# سلطنة عمان 1
# Guyana 1
# Spagna 1
# Uganda 1
# Sint Maarten 1
# Kuwait 1
# Egitto 1
# Japón 1
# Itália 1
# Gibraltar 1
# Czech Republic 1
# Roumanie 1
# Frankreich 1
# Norge 1
# Belize 1
# Srbija 1
# Grenada 1
# Japão 1
# Japon 1
# Nicaragua 1
# Frankrijk 1
# 일본 1
# Georgia 1
# Aland Islands 1
# Israel 1
# Espainia 1
# Unkari 1
# Slovenská republika 1
# Germania 1
# المملكة العربية السعودية 1
# Volksrepublik China 1
# Crna Gora 1
# Guadeloupe 1
# Egypt 1
# Republic of Belarus 1
# Curazoa 1
# Reino de Marruecos 1
# Lituania 1
# Україна 1

# %%
### only for the ones with country and photo
reversed_b = defaultdict(list)
for tweetID in b:
    reversed_b[dictPlace[tweetID]].append(tweetID)
print "Total countries", len(reversed_b) 

#order dict per popularity
for k in sorted(reversed_b, key=lambda k: len(reversed_b[k]), reverse=True):
        print k, len(reversed_b[k])
# Out:
# Total countries 76
# United States 262
# United Kingdom 89
# Canada 39
# Italia 23
# 日本 19
# Australia 15
# Malaysia 15
# Ireland 13
# India 12
# Republic of the Philippines 10
# España 9
# Colombia 8
# México 7
# France 6
# Indonesia 6
# Deutschland 6
# South Africa 6
# Japan 6
# Italy 5
# Argentina 4
# Nederland 4
# भारत 3
# Germany 3
# Thailand 3
# Österreich 3
# Espanya 3
# Mexico 3
# Peru 3
# Kingdom of Saudi Arabia 2
# Lithuania 2
# Brasil 2
# Venezuela 2
# Magyarország 2
# Chile 2
# Belgium 2
# The Netherlands 2
# Türkiye 2
# ประเทศไทย 2
# Brazil 1
# Qatar 1
# Crna Gora 1
# Canadá 1
# Costa Rica 1
# Morocco 1
# 中华人民共和国 1
# Sri Lanka 1
# Nigeria 1
# Ecuador 1
# Bangladesh 1
# Singapore 1
# Frankreich 1
# Cameroon 1
# Zambia 1
# Spain 1
# Schweiz 1
# Sverige 1
# Paraguay 1
# Новая Зеландия 1
# Suomi 1
# Россия 1
# Estados Unidos 1
# Kenya 1
# Switzerland 1
# New Zealand 1
# België 1
# Bulgaria 1
# Pakistan 1
# 台灣 1
# United Arab Emirates 1
# Guam 1
# Austria 1
# Japon 1
# Republic of Serbia 1
# République populaire de Chine 1
# Albania 1
# Việt Nam 1

# %% [markdown]
# ## Visualize wordcount

# %%
# better look on the server

# %% [markdown]
# ## Test user location field for 1000

# %%
from location import locations
from location.get_place_from_user_location import getUserLocation, inferCountryFromCity

countries = locations.Countries.loadFromFile()
cities = locations.Cities.loadFromFile()
citiesAscii = locations.Cities.loadFromFile(ascii=True)
ccDict = locations.Countries.countryCodeDict(countries)

i = 0
for tweet_id, user_loc in dictUserLocation.iteritems():
    i += 1
    user_cities, user_countries = getUserLocation(user_loc, citiesAscii, countries)
    inferred_countries = inferCountryFromCity(user_cities, citiesAscii, ccDict)
    print
    for city in user_cities:
        print citiesAscii[city], ccDict[citiesAscii[city][4]]
    print user_loc, user_cities, user_countries, inferred_countries   
    if i % 1000 == 0:
        break
# Out:
#  current dir:  /Users/muntean/Documents/workspace/food101
# ./location/countryInfo.txt
# All countries:  254
# All cities:  22312
# All cities:  22251
#
# (u'johannesburg', u'Johannesburg', 28.04363, -26.20227, u'ZA', 2026469, u'Africa/Johannesburg') south africa
# Johannesburg, South Africa set([u'johannesburg']) set([u'south africa']) set([u'south africa'])
#
# UK set([]) set([u'united kingdom']) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles, CA set([u'los angeles']) set([]) set([u'united states'])
#
# Southend set([]) set([]) None
#
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Florida, USA set([u'florida']) set([]) set([u'uruguay'])
#
# everywhere set([]) set([]) None
#
# (u'madrid', u'Madrid', -3.70256, 40.4165, u'ES', 3255944, u'Europe/Madrid') spain
# Madrid, España set([u'madrid']) set([]) set([u'spain'])
#
# (u'bolton', u'Bolton', -2.43333, 53.58333, u'GB', 141331, u'Europe/London') united kingdom
# Bolton Abbey, Skipton set([u'bolton']) set([]) set([u'united kingdom'])
#
# (u'ventura', u'Ventura', -119.29317, 34.27834, u'US', 96769, u'America/Los_Angeles') united states
# Ventura, CA set([u'ventura']) set([]) set([u'united states'])
#
# (u'sioux city', u'Sioux City', -96.40031, 42.49999, u'US', 82684, u'America/Chicago') united states
#  North Sioux City, SD. set([u'sioux city']) set([]) set([u'united states'])
#
# (u'brighton', u'Brighton', -104.82053, 39.98526, u'US', 33352, u'America/Denver') united states
# Brighton, England set([u'brighton']) set([u'united kingdom']) set([u'united states'])
#
# California set([]) set([]) None
#
# Philippines set([]) set([u'philippines']) None
#
# Roma, Lazio set([]) set([]) None
#
# California, USA set([]) set([]) None
#
# (u'las vegas', u'Las Vegas', -115.13722, 36.17497, u'US', 583756, u'America/Los_Angeles') united states
# Las Vegas NV set([u'las vegas']) set([]) set([u'united states'])
#
# (u'manchester', u'Manchester', -71.45479, 42.99564, u'US', 109565, u'America/New_York') united states
# Manchester Withington set([u'manchester']) set([]) set([u'united states'])
#
# Hogwarts set([]) set([]) None
#
# Ohio, USA set([]) set([]) None
#
# Wherever Dilip Is set([]) set([]) None
#
# (u'belleville', u'Belleville', -74.15014, 40.79371, u'US', 36878, u'America/New_York') united states
# Belleville, Illinois set([u'belleville']) set([]) set([u'united states'])
#
# New York set([]) set([]) None
#
# (u'scranton', u'Scranton', -75.6649, 41.40916, u'US', 76089, u'America/New_York') united states
# Scranton, Pa set([u'scranton']) set([]) set([u'united states'])
#
# (u'stillwater', u'Stillwater', -92.80604, 45.05636, u'US', 18225, u'America/Chicago') united states
# Stillwater MN set([u'stillwater']) set([]) set([u'united states'])
#
# Nueva York, USA set([]) set([]) None
#
# (u'addison', u'Addison', -87.98896, 41.9317, u'US', 36942, u'America/Chicago') united states
# Addison set([u'addison']) set([]) set([u'united states'])
#
# (u'kennesaw', u'Kennesaw', -84.61549, 34.02343, u'US', 29783, u'America/New_York') united states
# Kennesaw, GA set([u'kennesaw']) set([]) set([u'united states'])
#
# (u'columbus', u'Columbus', -97.36838, 41.42973, u'US', 22111, u'America/Chicago') united states
# The Best Side of Columbus set([u'columbus']) set([]) set([u'united states'])
#
# Milano, Lombardia set([]) set([]) None
#
# The Bakery set([]) set([]) None
#
# Wherever the plane lands set([]) set([]) None
#
# (u'manchester', u'Manchester', -71.45479, 42.99564, u'US', 109565, u'America/New_York') united states
# Manchester set([u'manchester']) set([]) set([u'united states'])
#
# New Zealand (NZ) set([]) set([u'new zealand']) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London United Kingdom set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# New York, USA set([]) set([]) None
#
# (u'chapel hill', u'Chapel Hill', -79.05584, 35.9132, u'US', 57233, u'America/New_York') united states
# (u'durham', u'Durham', -78.89862, 35.99403, u'US', 228330, u'America/New_York') united states
# (u'raleigh', u'Raleigh', -78.63861, 35.7721, u'US', 403892, u'America/New_York') united states
# Raleigh Durham Chapel Hill set([u'chapel hill', u'durham', u'raleigh']) set([]) set([u'united states'])
#
# (u'sydney', u'Sydney', -60.1831, 46.1351, u'CA', 105968, u'America/Glace_Bay') canada
# Sydney, Australia set([u'sydney']) set([u'australia']) set([u'canada'])
#
# (u'atlanta', u'Atlanta', -84.38798, 33.749, u'US', 420003, u'America/New_York') united states
# Atlanta set([u'atlanta']) set([]) set([u'united states'])
#
# (u'butuan', u'Butuan', 125.54361, 8.94917, u'PH', 309709, u'Asia/Manila') philippines
# Butuan City, Philippines set([u'butuan']) set([u'philippines']) set([u'philippines'])
#
# California, USA set([]) set([]) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# los angeles set([u'los angeles']) set([]) set([u'united states'])
#
# California, USA set([]) set([]) None
#
# (u'florence', u'Florence', -111.38734, 33.03145, u'US', 25536, u'America/Phoenix') united states
# Florence, AL set([u'florence']) set([]) set([u'united states'])
#
# South East England set([]) set([u'united kingdom']) None
#
# UK set([]) set([u'united kingdom']) None
#
# (u'independence', u'Independence', -94.41551, 39.09112, u'US', 116830, u'America/Chicago') united states
# Independence set([u'independence']) set([]) set([u'united states'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# Bromley, London set([u'london']) set([]) set([u'united kingdom'])
#
# (u'chicago', u'Chicago', -87.65005, 41.85003, u'US', 2695598, u'America/Chicago') united states
# LA, NYC, Chicago, D.C., Vegas set([u'chicago']) set([]) set([u'united states'])
#
# (u'homestead', u'Homestead', -80.47756, 25.46872, u'US', 60512, u'America/New_York') united states
# Homestead, FL set([u'homestead']) set([]) set([u'united states'])
#
# New York, USA set([]) set([]) None
#
# https://goo.gl/maps/PDJt2jKny6 set([]) set([]) None
#
# World set([]) set([]) None
#
# (u'las vegas', u'Las Vegas', -115.13722, 36.17497, u'US', 583756, u'America/Los_Angeles') united states
# Las Vegas, NV set([u'las vegas']) set([]) set([u'united states'])
#
# (u'washington', u'Washington', -113.50829, 37.13054, u'US', 18761, u'America/Denver') united states
# Washington set([u'washington']) set([]) set([u'united states'])
#
# (u'bengaluru', u'Bengaluru', 77.59369, 12.97194, u'IN', 5104047, u'Asia/Kolkata') india
# Bengaluru, Karnataka set([u'bengaluru']) set([]) set([u'india'])
#
# (u'mar del plata', u'Mar del Plata', -57.55754, -38.00228, u'AR', 553935, u'America/Argentina/Buenos_Aires') argentina
# Mar del plata Argentina set([u'mar del plata']) set([u'argentina']) set([u'argentina'])
#
# (u'parma', u'Parma', -81.72291, 41.40477, u'US', 81601, u'America/New_York') united states
# Parma set([u'parma']) set([]) set([u'united states'])
#
# Discovering new flavors set([]) set([]) None
#
# Worldwide set([]) set([]) None
#
# (u'singapore', u'Singapore', 103.85007, 1.28967, u'SG', 3547809, u'Asia/Singapore') singapore
# Singapore set([u'singapore']) set([u'singapore']) set([u'singapore'])
#
# (u'harrisonburg', u'Harrisonburg', -78.86892, 38.44957, u'US', 48914, u'America/New_York') united states
# Harrisonburg, VA set([u'harrisonburg']) set([]) set([u'united states'])
#
# Universe set([]) set([]) None
#
# (u'seattle', u'Seattle', -122.33207, 47.60621, u'US', 608660, u'America/Los_Angeles') united states
# Seattle, WA set([u'seattle']) set([]) set([u'united states'])
#
# sul tatami set([]) set([]) None
#
# (u'sheffield', u'Sheffield', -1.4659, 53.38297, u'GB', 447047, u'Europe/London') united kingdom
# Sheffield, England set([u'sheffield']) set([u'united kingdom']) set([u'united kingdom'])
#
# United States set([]) set([u'united states']) None
#
# 韓ヲタ set([]) set([]) None
#
# (u'cairo', u'Cairo', 31.24967, 30.06263, u'EG', 7734614, u'Africa/Cairo') egypt
# Cairo/Egypt set([u'cairo']) set([u'egypt']) set([u'egypt'])
#
# 38.593099,-90.331922 set([]) set([]) None
#
# (u'oxford', u'Oxford', -84.74523, 39.507, u'US', 21371, u'America/New_York') united states
# Oxford  set([u'oxford']) set([]) set([u'united states'])
#
# (u'dublin', u'Dublin', -121.93579, 37.70215, u'US', 46036, u'America/Los_Angeles') united states
# Dublin, International  set([u'dublin']) set([]) set([u'united states'])
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Studio City, Los Angeles set([u'los angeles']) set([]) set([u'united states'])
#
# England, United Kingdom set([]) set([u'united kingdom']) None
#
# Ｔｏｋｙｏ　toka set([]) set([]) None
#
# Hauts-de-Seine, Ile-de-France set([]) set([]) None
#
# CABA set([]) set([]) None
#
# (u'lyon', u'Lyon', 4.84671, 45.74846, u'FR', 472317, u'Europe/Paris') france
# Lyon France set([u'lyon']) set([u'france']) set([u'france'])
#
# (u'westminster', u'Westminster', -105.0372, 39.83665, u'US', 106114, u'America/Denver') united states
# (u'new westminster', u'New Westminster', -122.91092, 49.20678, u'CA', 58549, u'America/Vancouver') canada
# New Westminster, BC set([u'westminster', u'new westminster']) set([]) None
#
# (u'barcelona', u'Barcelona', -64.68618, 10.13625, u'VE', 424795, u'America/Caracas') venezuela
# Barcelona set([u'barcelona']) set([]) set([u'venezuela'])
#
# (u"l'aquila", u"L'Aquila", 13.39954, 42.35055, u'IT', 33691, u'Europe/Rome') italy
# l'aquila set([u"l'aquila"]) set([]) set([u'italy'])
#
# Iceland set([]) set([u'iceland']) None
#
# (u'cheshire', u'Cheshire', -72.90066, 41.49899, u'US', 29443, u'America/New_York') united states
# (u'hale', u'Hale', -2.33271, 53.37831, u'GB', 15315, u'Europe/London') united kingdom
# Hale, Cheshire set([u'cheshire', u'hale']) set([]) None
#
# الدوحة, دولة قطر set([]) set([]) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles, CA set([u'los angeles']) set([]) set([u'united states'])
#
# (u'chicago', u'Chicago', -87.65005, 41.85003, u'US', 2695598, u'America/Chicago') united states
# Chicago set([u'chicago']) set([]) set([u'united states'])
#
# (u'helsinki', u'Helsinki', 24.93545, 60.16952, u'FI', 558457, u'Europe/Helsinki') finland
# Helsinki, Finland set([u'helsinki']) set([u'finland']) set([u'finland'])
#
# (u'liverpool', u'Liverpool', -2.97794, 53.41058, u'GB', 468945, u'Europe/London') united kingdom
# Liverpool set([u'liverpool']) set([]) set([u'united kingdom'])
#
# (u'las vegas', u'Las Vegas', -115.13722, 36.17497, u'US', 583756, u'America/Los_Angeles') united states
# Las Vegas, Nevada set([u'las vegas']) set([]) set([u'united states'])
#
# Θεσσαλονίκη, Ελλάς set([]) set([]) None
#
# https://goo.gl/maps/PDJt2jKny6 set([]) set([]) None
#
# Саратов set([]) set([]) None
#
# Flovilla Georgia US 30216-2105 set([]) set([u'georgia']) None
#
# (u'blackpool', u'Blackpool', -3.05, 53.81667, u'GB', 143101, u'Europe/London') united kingdom
# blackpool set([u'blackpool']) set([]) set([u'united kingdom'])
#
# (u'salt lake city', u'Salt Lake City', -111.89105, 40.76078, u'US', 186440, u'America/Denver') united states
# Salt Lake City, UT set([u'salt lake city']) set([]) set([u'united states'])
#
# (u'singapore', u'Singapore', 103.85007, 1.28967, u'SG', 3547809, u'Asia/Singapore') singapore
# Singapore set([u'singapore']) set([u'singapore']) set([u'singapore'])
#
# (u'gr\xe0cia', u'Gracia', 2.15641, 41.40237, u'ES', 120087, u'Europe/Madrid') spain
# (u'barcelona', u'Barcelona', -64.68618, 10.13625, u'VE', 424795, u'America/Caracas') venezuela
# Barcelona, Gracia set([u'gracia', u'barcelona']) set([]) None
#
# (u'miami', u'Miami', -80.19366, 25.77427, u'US', 399457, u'America/New_York') united states
# Miami, FL set([u'miami']) set([]) set([u'united states'])
#
# (u'cornwall', u'Cornwall', -74.72815, 45.01809, u'CA', 48821, u'America/Toronto') canada
# Cornwall set([u'cornwall']) set([]) set([u'canada'])
#
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Florida, USA set([u'florida']) set([]) set([u'uruguay'])
#
# (u'san diego', u'San Diego', -117.15726, 32.71533, u'US', 1307402, u'America/Los_Angeles') united states
# (u'san', u'San', -4.89562, 13.30335, u'ML', 24811, u'Africa/Bamako') mali
# San Diego, CA set([u'san diego', u'san']) set([]) None
#
# England, UK set([]) set([u'united kingdom']) None
#
# Earth set([]) set([]) None
#
# France set([]) set([u'france']) None
#
# Worldwide set([]) set([]) None
#
# (u'darmstadt', u'Darmstadt', 8.65027, 49.87167, u'DE', 140385, u'Europe/Berlin') germany
# Darmstadt, Germany set([u'darmstadt']) set([u'germany']) set([u'germany'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, England set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# Duque Ahumada 14.Pso maritimo set([]) set([]) None
#
# New Jersey, USA set([]) set([u'jersey']) None
#
# デリッシュキッチン DELISHKITCHEN set([]) set([]) None
#
# (u'penzance', u'Penzance', -5.53715, 50.11861, u'GB', 20812, u'Europe/London') united kingdom
# Penzance, England set([u'penzance']) set([u'united kingdom']) set([u'united kingdom'])
#
# Roma set([]) set([]) None
#
# Northern France / Belgium set([]) set([u'belgium', u'france']) None
#
# (u'swansea', u'Swansea', -71.18977, 41.74816, u'US', 16525, u'America/New_York') united states
# swansea set([u'swansea']) set([]) set([u'united states'])
#
# (u'boca raton', u'Boca Raton', -80.0831, 26.35869, u'US', 84392, u'America/New_York') united states
# Boca Raton, Fl set([u'boca raton']) set([]) set([u'united states'])
#
# (u'san antonio', u'San Antonio', -98.49363, 29.42412, u'US', 1327407, u'America/Chicago') united states
# (u'san', u'San', -4.89562, 13.30335, u'ML', 24811, u'Africa/Bamako') mali
# San Antonio, Texas set([u'san antonio', u'san']) set([]) None
#
# USA set([]) set([]) None
#
# (u'madison', u'Madison', -89.40123, 43.07305, u'US', 233209, u'America/Chicago') united states
# Madison WI, USA set([u'madison']) set([]) set([u'united states'])
#
# (u'florence', u'Florence', -111.38734, 33.03145, u'US', 25536, u'America/Phoenix') united states
# Florence, AL set([u'florence']) set([]) set([u'united states'])
#
# (u'seattle', u'Seattle', -122.33207, 47.60621, u'US', 608660, u'America/Los_Angeles') united states
# Seattle, WA set([u'seattle']) set([]) set([u'united states'])
#
# (u'allen', u'Allen', -96.67055, 33.10317, u'US', 84246, u'America/Chicago') united states
# Grayson Allen is a douche bag  set([u'allen']) set([]) set([u'united states'])
#
# (u'charlotte', u'Charlotte', -80.84313, 35.22709, u'US', 731424, u'America/New_York') united states
# Charlotte, NC set([u'charlotte']) set([]) set([u'united states'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# Hanwell, London set([u'london']) set([]) set([u'united kingdom'])
#
# Living with @kyroskoh (SG) set([]) set([]) None
#
# Oman set([]) set([u'oman']) None
#
# (u'guanajuato', u'Guanajuato', -101.2591, 21.01858, u'MX', 78364, u'America/Mexico_City') mexico
# León, Guanajuato set([u'guanajuato']) set([]) set([u'mexico'])
#
# (u'j\u0101wad', u'Jawad', 74.86261, 24.59916, u'IN', 16887, u'Asia/Kolkata') india
# Chez Jawad set([u'jawad']) set([]) set([u'india'])
#
# (u'miami', u'Miami', -80.19366, 25.77427, u'US', 399457, u'America/New_York') united states
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Miami, Florida USA set([u'miami', u'florida']) set([]) None
#
# Everywhere : (17+16=)33 & 237 set([]) set([]) None
#
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Florida, USA set([u'florida']) set([]) set([u'uruguay'])
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles, CA set([u'los angeles']) set([]) set([u'united states'])
#
# (u'boadilla del monte', u'Boadilla del Monte', -3.87835, 40.405, u'ES', 43414, u'Europe/Madrid') spain
# Boadilla del Monte set([u'boadilla del monte']) set([]) set([u'spain'])
#
# (u'birmingham', u'Birmingham', -83.21132, 42.5467, u'US', 20103, u'America/Detroit') united states
# Birmingham/Muscle Shoals set([u'birmingham']) set([]) set([u'united states'])
#
# (u'homestead', u'Homestead', -80.47756, 25.46872, u'US', 60512, u'America/New_York') united states
# Homestead, FL set([u'homestead']) set([]) set([u'united states'])
#
# (u'houston', u'Houston', -95.36327, 29.76328, u'US', 2099451, u'America/Chicago') united states
# TheWorld- Houston,Tx.,U.S.A.  set([u'houston']) set([]) set([u'united states'])
#
# (u'cedar rapids', u'Cedar Rapids', -91.64407, 42.00833, u'US', 126326, u'America/Chicago') united states
# Cedar Rapids, IA set([u'cedar rapids']) set([]) set([u'united states'])
#
# (u'chester', u'Chester', -77.44165, 37.35682, u'US', 20987, u'America/New_York') united states
# Chester set([u'chester']) set([]) set([u'united states'])
#
# (u'chippenham', u'Chippenham', -2.12472, 51.46, u'GB', 36890, u'Europe/London') united kingdom
# Chippenham, Wiltshire set([u'chippenham']) set([]) set([u'united kingdom'])
#
# (u'battle creek', u'Battle Creek', -85.17816, 42.3173, u'US', 52347, u'America/Detroit') united states
# Battle Creek, MI set([u'battle creek']) set([]) set([u'united states'])
#
# New York, USA set([]) set([]) None
#
# (u'biggleswade', u'Biggleswade', -0.26493, 52.08652, u'GB', 15726, u'Europe/London') united kingdom
# Biggleswade, England set([u'biggleswade']) set([u'united kingdom']) set([u'united kingdom'])
#
# (u'miami', u'Miami', -80.19366, 25.77427, u'US', 399457, u'America/New_York') united states
# Miami, FL set([u'miami']) set([]) set([u'united states'])
#
# (u'long beach', u'Long Beach', -118.18923, 33.76696, u'US', 462257, u'America/Los_Angeles') united states
# Long Beach, CA set([u'long beach']) set([]) set([u'united states'])
#
# United States set([]) set([u'united states']) None
#
# Illinois, USA set([]) set([]) None
#
# (u'charlotte', u'Charlotte', -80.84313, 35.22709, u'US', 731424, u'America/New_York') united states
# Charlotte, NC set([u'charlotte']) set([]) set([u'united states'])
#
# (u'honolulu', u'Honolulu', -157.85833, 21.30694, u'US', 371657, u'Pacific/Honolulu') united states
# Honolulu, HI set([u'honolulu']) set([]) set([u'united states'])
#
# Comunidad Valenciana, España set([]) set([]) None
#
# (u'blackpool', u'Blackpool', -3.05, 53.81667, u'GB', 143101, u'Europe/London') united kingdom
# 390-392 Promenade, Blackpool. set([u'blackpool']) set([]) set([u'united kingdom'])
#
# USA|EUROPE|ASIA|GLOBAL✈️ set([]) set([]) None
#
# Living with @kyroskoh (SG) set([]) set([]) None
#
# ‍19 ‍さい    福岡こども set([]) set([]) None
#
# (u'ontario', u'Ontario', -117.65089, 34.06334, u'US', 163924, u'America/Los_Angeles') united states
# (u'hamilton', u'Hamilton', -84.56134, 39.3995, u'US', 62477, u'America/New_York') united states
# Hamilton, Ontario set([u'ontario', u'hamilton']) set([]) set([u'united states'])
#
# (u'ottawa', u'Ottawa', -88.84258, 41.34559, u'US', 18768, u'America/Chicago') united states
# Ottawa set([u'ottawa']) set([]) set([u'united states'])
#
# 161 River Ave., Patchogue, NY set([]) set([]) None
#
# (u'bangkok', u'Bangkok', 100.50144, 13.75398, u'TH', 5104476, u'Asia/Bangkok') thailand
# Bangkok, Thailand set([u'bangkok']) set([u'thailand']) set([u'thailand'])
#
# Egypt set([]) set([u'egypt']) None
#
# (u'asia', u'Asia', 122.5164, 9.5506, u'PH', 23546, u'Asia/Manila') philippines
# Asia set([u'asia']) set([]) set([u'philippines'])
#
# São Paulo set([]) set([]) None
#
# 日本 神奈 set([]) set([]) None
#
# (u'marbella', u'Marbella', -4.88583, 36.51543, u'ES', 134623, u'Europe/Madrid') spain
# Marbella, Spain set([u'marbella']) set([u'spain']) set([u'spain'])
#
# (u'chicago', u'Chicago', -87.65005, 41.85003, u'US', 2695598, u'America/Chicago') united states
# Chicago, IL set([u'chicago']) set([]) set([u'united states'])
#
# (u'jakarta', u'Jakarta', 106.84513, -6.21462, u'ID', 8540121, u'Asia/Jakarta') indonesia
# Rawamangun, East Jakarta set([u'jakarta']) set([]) set([u'indonesia'])
#
# México set([]) set([]) None
#
# Bangalore set([]) set([]) None
#
# 世田谷区 set([]) set([]) None
#
# https://goo.gl/maps/PDJt2jKny6 set([]) set([]) None
#
# (u'poitiers', u'Poitiers', 0.33333, 46.58333, u'FR', 85960, u'Europe/Paris') france
# Poitiers set([u'poitiers']) set([]) set([u'france'])
#
# (u'oakland', u'Oakland', -122.2708, 37.80437, u'US', 390724, u'America/Los_Angeles') united states
# Oakland, CA set([u'oakland']) set([]) set([u'united states'])
#
# (u'belfast', u'Belfast', -5.92541, 54.59682, u'GB', 274770, u'Europe/London') united kingdom
# Belfast, Northern Ireland set([u'belfast']) set([u'ireland']) set([u'united kingdom'])
#
# (u'rotterdam', u'Rotterdam', -73.97096, 42.78702, u'US', 20652, u'America/New_York') united states
# Rotterdam Area, Netherlands set([u'rotterdam']) set([u'netherlands']) set([u'united states'])
#
# (u'hyderabad', u'Hyderabad', 68.37366, 25.39242, u'PK', 1386330, u'Asia/Karachi') pakistan
# (u'dubai', u'Dubai', 55.17128, 25.0657, u'AE', 1137347, u'Asia/Dubai') united arab emirates
# Hyderabad & Dubai set([u'hyderabad', u'dubai']) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# (u'city of london', u'City of London', -0.09184, 51.51279, u'GB', 7556900, u'Europe/London') united kingdom
# City of London, London set([u'london', u'city of london']) set([]) set([u'united kingdom'])
#
# (u'youngstown', u'Youngstown', -80.64952, 41.09978, u'US', 66982, u'America/New_York') united states
# Youngstown OH set([u'youngstown']) set([]) set([u'united states'])
#
# (u'santa cruz', u'Santa Cruz', -122.0308, 36.97412, u'US', 59946, u'America/Los_Angeles') united states
# Santa Cruz, CA set([u'santa cruz']) set([]) set([u'united states'])
#
# (u'portland', u'Portland', -122.67621, 45.52345, u'US', 583776, u'America/Los_Angeles') united states
# Portland, Maine set([u'portland']) set([]) set([u'united states'])
#
# (u'cleveland', u'Cleveland', -81.69541, 41.4995, u'US', 396815, u'America/New_York') united states
# Cleveland, OH set([u'cleveland']) set([]) set([u'united states'])
#
# Boschi Sant'Anna, Veneto set([]) set([]) None
#
# (u'cape town', u'Cape Town', 18.42322, -33.92584, u'ZA', 3433441, u'Africa/Johannesburg') south africa
# 137 Waterkant St, Cape Town set([u'cape town']) set([]) set([u'south africa'])
#
# (u'solihull', u'Solihull', -1.78094, 52.41426, u'GB', 96267, u'Europe/London') united kingdom
# Solihull, England set([u'solihull']) set([u'united kingdom']) set([u'united kingdom'])
#
# (u'antequera', u'Antequera', -4.56123, 37.01938, u'ES', 45168, u'Europe/Madrid') spain
# Antequera, España set([u'antequera']) set([]) set([u'spain'])
#
# (u'grants pass', u'Grants Pass', -123.33067, 42.43933, u'US', 34533, u'America/Los_Angeles') united states
# Grants Pass, OR set([u'grants pass']) set([]) set([u'united states'])
#
# (u'bekasi', u'Bekasi', 106.9896, -6.2349, u'ID', 1520119, u'Asia/Jakarta') indonesia
# Bekasi set([u'bekasi']) set([]) set([u'indonesia'])
#
# India set([]) set([u'india']) None
#
# (u'venezuela', u'Venezuela', -78.79336, 21.73748, u'CU', 16601, u'America/Havana') cuba
# (u'caracas', u'Caracas', -66.87919, 10.48801, u'VE', 3000000, u'America/Caracas') venezuela
# Venezuela. Caracas set([u'venezuela', u'caracas']) set([u'venezuela']) None
#
# (u'san mateo', u'San Mateo', -67.42365, 10.21302, u'VE', 50401, u'America/Caracas') venezuela
# (u'san', u'San', -4.89562, 13.30335, u'ML', 24811, u'Africa/Bamako') mali
# San Mateo, CA set([u'san mateo', u'san']) set([]) None
#
# Inglaterra, Reino Unido, set([]) set([]) None
#
# 無料でいいから34歳の童貞貰ってくれる可愛い女の子募集中 set([]) set([]) None
#
# (u'philadelphia', u'Philadelphia', -75.16379, 39.95233, u'US', 1526006, u'America/New_York') united states
# Philadelphia, PA set([u'philadelphia']) set([]) set([u'united states'])
#
# Online ~ Worldwide set([]) set([]) None
#
# Discovering new flavors set([]) set([]) None
#
# (u'dublin', u'Dublin', -121.93579, 37.70215, u'US', 46036, u'America/Los_Angeles') united states
# Dublin City, Ireland set([u'dublin']) set([u'ireland']) set([u'united states'])
#
# (u'greenville', u'Greenville', -96.11081, 33.13845, u'US', 25557, u'America/Chicago') united states
# Greenville NC set([u'greenville']) set([]) set([u'united states'])
#
# (u'cardiff', u'Cardiff', -3.18, 51.48, u'GB', 302139, u'Europe/London') united kingdom
# Cardiff, South Wales, UK set([u'cardiff']) set([u'united kingdom']) set([u'united kingdom'])
#
# Italia set([]) set([]) None
#
# Uk set([]) set([u'united kingdom']) None
#
# (u'reigate', u'Reigate', -0.20582, 51.23736, u'GB', 52123, u'Europe/London') united kingdom
# (u'redhill', u'Redhill', -0.17044, 51.24048, u'GB', 51559, u'Europe/London') united kingdom
# Reigate, Redhill and Cheam set([u'reigate', u'redhill']) set([]) set([u'united kingdom'])
#
# New York, USA set([]) set([]) None
#
# New York, USA set([]) set([]) None
#
# (u'anderson', u'Anderson', -85.68025, 40.10532, u'US', 56129, u'America/Indiana/Indianapolis') united states
# Anderson set([u'anderson']) set([]) set([u'united states'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London  set([u'london']) set([]) set([u'united kingdom'])
#
# (u'santiago', u'Santiago', 121.5487, 16.68808, u'PH', 108414, u'Asia/Manila') philippines
# SANTIAGO,STI, REP. DOM. set([u'santiago']) set([]) set([u'philippines'])
#
# Abercrombie set([]) set([]) None
#
# Ocean Township, NJ set([]) set([]) None
#
# iPhone: 51.512405,-0.150595 set([]) set([]) None
#
# Enriching Lives, South Africa set([]) set([u'south africa']) None
#
# New Jersey, USA set([]) set([u'jersey']) None
#
# 219 High Road, E18 2PB set([]) set([]) None
#
# (u'hamburg', u'Hamburg', 10.01534, 53.57532, u'DE', 1739117, u'Europe/Berlin') germany
# Hamburg, Deutschland set([u'hamburg']) set([]) set([u'germany'])
#
# (u'miami', u'Miami', -80.19366, 25.77427, u'US', 399457, u'America/New_York') united states
# Miami, FL set([u'miami']) set([]) set([u'united states'])
#
# (u'new york city', u'New York City', -74.00597, 40.71427, u'US', 8175133, u'America/New_York') united states
# New York City set([u'new york city']) set([]) set([u'united states'])
#
# Old Saybrook, CT set([]) set([]) None
#
# (u'birmingham', u'Birmingham', -83.21132, 42.5467, u'US', 20103, u'America/Detroit') united states
# Birmingham, UK set([u'birmingham']) set([u'united kingdom']) set([u'united states'])
#
# (u'dh\u0101ka', u'Dhaka', 85.16698, 26.67479, u'IN', 36111, u'Asia/Kolkata') india
# (u'sylhet', u'Sylhet', 91.87198, 24.89904, u'BD', 237000, u'Asia/Dhaka') bangladesh
# (u'habiganj', u'Habiganj', 91.41299, 24.38044, u'BD', 88760, u'Asia/Dhaka') bangladesh
# Nabiganj , Habiganj , Sylhet , Dhaka , Bangladesh set([u'dhaka', u'sylhet', u'habiganj']) set([u'bangladesh']) None
#
# (u'groningen', u'Groningen', 6.56667, 53.21917, u'NL', 181194, u'Europe/Amsterdam') netherlands
# Groningen, The Netherlands set([u'groningen']) set([u'netherlands']) set([u'netherlands'])
#
# (u'indianapolis', u'Indianapolis', -86.15804, 39.76838, u'US', 829718, u'America/Indiana/Indianapolis') united states
# Indianapolis, IN Colt's Nation set([u'indianapolis']) set([]) set([u'united states'])
#
# (u'paris', u'Paris', -95.55551, 33.66094, u'US', 25171, u'America/Chicago') united states
# Paris set([u'paris']) set([]) set([u'united states'])
#
# 日本 set([]) set([]) None
#
# Where Ever You Go I Will Be! set([]) set([]) None
#
# Making My Dreams Reality set([]) set([]) None
#
# (u'linden', u'Linden', -74.24459, 40.62205, u'US', 40499, u'America/New_York') united states
# (u'rockford', u'Rockford', -89.094, 42.27113, u'US', 152871, u'America/Chicago') united states
# 6392 Linden Road Rockford, IL set([u'linden', u'rockford']) set([]) set([u'united states'])
#
# (u'miami', u'Miami', -80.19366, 25.77427, u'US', 399457, u'America/New_York') united states
# Miami Shores, FL set([u'miami']) set([]) set([u'united states'])
#
# Northern Ireland set([]) set([u'ireland']) None
#
# (u'grand rapids', u'Grand Rapids', -85.66809, 42.96336, u'US', 188040, u'America/Detroit') united states
# Grand Rapids, MI set([u'grand rapids']) set([]) set([u'united states'])
#
# (u'washington', u'Washington', -113.50829, 37.13054, u'US', 18761, u'America/Denver') united states
# Washington, D.C. set([u'washington']) set([]) set([u'united states'])
#
# (u'kolkata', u'Kolkata', 88.36304, 22.56263, u'IN', 4631392, u'Asia/Kolkata') india
# Kolkata set([u'kolkata']) set([]) set([u'india'])
#
# New York, USA set([]) set([]) None
#
# Kyrgyzstan set([]) set([u'kyrgyzstan']) None
#
# (u'tuxtla', u'Tuxtla', -93.11308, 16.75973, u'MX', 481128, u'America/Mexico_City') mexico
# Tuxtla Gutiérrez, Chiapas. Mex set([u'tuxtla']) set([]) set([u'mexico'])
#
# (u'hot springs', u'Hot Springs', -93.05518, 34.5037, u'US', 35193, u'America/Chicago') united states
# (u'springs', u'Springs', 28.4, -26.25, u'ZA', 186394, u'Africa/Johannesburg') south africa
# Hot Springs, Ar set([u'hot springs', u'springs']) set([]) None
#
# New York set([]) set([]) None
#
# Discovering new flavors set([]) set([]) None
#
# チーム大地 set([]) set([]) None
#
# Alabama set([]) set([]) None
#
# NY set([]) set([]) None
#
# (u'krefeld', u'Krefeld', 6.58615, 51.33921, u'DE', 237984, u'Europe/Berlin') germany
# Fischeln, Krefeld set([u'krefeld']) set([]) set([u'germany'])
#
# Wien, Österreich set([]) set([]) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles, CA set([u'los angeles']) set([]) set([u'united states'])
#
# Milky Way set([]) set([]) None
#
# (u'boston', u'Boston', -71.05977, 42.35843, u'US', 617594, u'America/New_York') united states
# Boston, MA set([u'boston']) set([]) set([u'united states'])
#
# Ai set([]) set([]) None
#
# United States set([]) set([u'united states']) None
#
# (u'paris', u'Paris', -95.55551, 33.66094, u'US', 25171, u'America/Chicago') united states
# Paloise exilée à Paris set([u'paris']) set([]) set([u'united states'])
#
# (u'madrid', u'Madrid', -3.70256, 40.4165, u'ES', 3255944, u'Europe/Madrid') spain
# Madrid, Comunidad de Madrid set([u'madrid']) set([]) set([u'spain'])
#
# (u'frederick', u'Frederick', -77.41054, 39.41427, u'US', 65239, u'America/New_York') united states
# 16 E. Patrick St  Frederick,MD set([u'frederick']) set([]) set([u'united states'])
#
# (u'rancho cucamonga', u'Rancho Cucamonga', -117.59311, 34.1064, u'US', 165269, u'America/Los_Angeles') united states
# Rancho Cucamonga, CA set([u'rancho cucamonga']) set([]) set([u'united states'])
#
# (u'jeddah', u'Jeddah', 39.19797, 21.54238, u'SA', 2867446, u'Asia/Riyadh') saudi arabia
# Jeddah set([u'jeddah']) set([]) set([u'saudi arabia'])
#
# New York, USA set([]) set([]) None
#
# (u'ami', u'Ami', 140.2, 36.03333, u'JP', 48256, u'Asia/Tokyo') japan
# ❧ khz.ami ❦  set([u'ami']) set([]) set([u'japan'])
#
# Milky Way set([]) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London set([u'london']) set([]) set([u'united kingdom'])
#
# Philippines set([]) set([u'philippines']) None
#
# #winesphere Brazil set([]) set([u'brazil']) None
#
# Alexis set([]) set([]) None
#
# Arkansas set([]) set([]) None
#
# (u'waterloo', u'Waterloo', -92.34296, 42.49276, u'US', 68406, u'America/Chicago') united states
# (u'sydney', u'Sydney', -60.1831, 46.1351, u'CA', 105968, u'America/Glace_Bay') canada
# Waterloo, Sydney  set([u'waterloo', u'sydney']) set([]) None
#
# (u'johannesburg', u'Johannesburg', 28.04363, -26.20227, u'ZA', 2026469, u'Africa/Johannesburg') south africa
# Johannesburg, South Africa set([u'johannesburg']) set([u'south africa']) set([u'south africa'])
#
# (u'lexington', u'Lexington', -71.2245, 42.44732, u'US', 31394, u'America/New_York') united states
# Lexington, SC set([u'lexington']) set([]) set([u'united states'])
#
# UK set([]) set([u'united kingdom']) None
#
# (u'colorado', u'Colorado', -51.97306, -22.8375, u'BR', 20449, u'America/Sao_Paulo') brazil
# (u'denver', u'Denver', -104.9847, 39.73915, u'US', 600158, u'America/Denver') united states
# Denver Colorado set([u'colorado', u'denver']) set([]) None
#
# (u'gurgaon', u'Gurgaon', 77.02635, 28.4601, u'IN', 197340, u'Asia/Kolkata') india
# Gurgaon, India set([u'gurgaon']) set([u'india']) set([u'india'])
#
# Weezyanner set([]) set([]) None
#
# (u'washington', u'Washington', -113.50829, 37.13054, u'US', 18761, u'America/Denver') united states
# Washington DC set([u'washington']) set([]) set([u'united states'])
#
# Canary Islands, Spain set([]) set([u'spain']) None
#
# (u'college station', u'College Station', -96.33441, 30.62798, u'US', 93857, u'America/Chicago') united states
# College Station, TX set([u'college station']) set([]) set([u'united states'])
#
# (u'leeds', u'Leeds', -1.54785, 53.79648, u'GB', 455123, u'Europe/London') united kingdom
# Leeds, England set([u'leeds']) set([u'united kingdom']) set([u'united kingdom'])
#
# (u'cocoa', u'Cocoa', -80.742, 28.38612, u'US', 17140, u'America/New_York') united states
# Cocoa Beach, FL set([u'cocoa']) set([]) set([u'united states'])
#
# (u'bangkok', u'Bangkok', 100.50144, 13.75398, u'TH', 5104476, u'Asia/Bangkok') thailand
# Bangkok, Thailand set([u'bangkok']) set([u'thailand']) set([u'thailand'])
#
# Malvern, PA set([]) set([]) None
#
# North Wales set([]) set([]) None
#
# (u'san francisco', u'San Francisco', -122.41942, 37.77493, u'US', 805235, u'America/Los_Angeles') united states
# (u'san', u'San', -4.89562, 13.30335, u'ML', 24811, u'Africa/Bamako') mali
# (u'bay', u'Bay', 121.28554, 14.18368, u'PH', 33547, u'Asia/Manila') philippines
# San Francisco Bay Area, CA set([u'san francisco', u'san', u'bay']) set([]) None
#
# ATLien set([]) set([]) None
#
# Penrose set([]) set([]) None
#
# (u'guayaquil', u'Guayaquil', -79.90795, -2.20584, u'EC', 1952029, u'America/Guayaquil') ecuador
# Guayaquil, Ecuador set([u'guayaquil']) set([u'ecuador']) set([u'ecuador'])
#
# (u'gravesend', u'Gravesend', 0.37371, 51.44138, u'GB', 54263, u'Europe/London') united kingdom
# (u'kent', u'Kent', -122.23484, 47.38093, u'US', 92411, u'America/Los_Angeles') united states
# gravesend kent set([u'gravesend', u'kent']) set([]) None
#
# 広島～大阪～神戸 set([]) set([]) None
#
# (u'omaha', u'Omaha', -95.94043, 41.25626, u'US', 408958, u'America/Chicago') united states
# Jobbers Canyon, Omaha, Neb. set([u'omaha']) set([]) set([u'united states'])
#
# (u'yonkers', u'Yonkers', -73.89875, 40.93121, u'US', 195976, u'America/New_York') united states
# Yonkers, NY set([u'yonkers']) set([]) set([u'united states'])
#
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Florida, USA set([u'florida']) set([]) set([u'uruguay'])
#
# United Kingdom set([]) set([u'united kingdom']) None
#
# (u'milan', u'Milan', 9.18951, 45.46427, u'IT', 1236837, u'Europe/Rome') italy
# Milan set([u'milan']) set([]) set([u'italy'])
#
# (u'oxford', u'Oxford', -84.74523, 39.507, u'US', 21371, u'America/New_York') united states
# North Oxford, MA set([u'oxford']) set([]) set([u'united states'])
#
# Gloucestershire set([]) set([]) None
#
# (u'suffolk', u'Suffolk', -76.58496, 36.72836, u'US', 84585, u'America/New_York') united states
# SUffolk County, NY set([u'suffolk']) set([]) set([u'united states'])
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles set([u'los angeles']) set([]) set([u'united states'])
#
# Allison set([]) set([]) None
#
# 全国どこかのラーメン屋さんの券売機そばの席 set([]) set([]) None
#
# (u'hollywood', u'Hollywood', -118.32674, 34.09834, u'US', 167664, u'America/Los_Angeles') united states
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Hollywood, Los Angeles set([u'hollywood', u'los angeles']) set([]) set([u'united states'])
#
# USA set([]) set([]) None
#
# ALIENS! set([]) set([]) None
#
# (u'jaguaruana', u'Jaguaruana', -37.78111, -4.83389, u'BR', 21790, u'America/Fortaleza') brazil
# Jaguaruana  set([u'jaguaruana']) set([]) set([u'brazil'])
#
# 91 set([]) set([]) None
#
# New South Wales, Australia set([]) set([u'australia']) None
#
# 1 ♡ T.O. set([]) set([]) None
#
# Under Riri's Umbrella ☂ set([]) set([]) None
#
# (u'ocala', u'Ocala', -82.14009, 29.1872, u'US', 56315, u'America/New_York') united states
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Ocala, Florida set([u'ocala', u'florida']) set([]) None
#
# الرياض, المملكة العربية السعودية set([]) set([]) None
#
# Niverville, Manitoba set([]) set([]) None
#
# Roma, Lazio set([]) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, UK set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# Venezia, Italy set([]) set([u'italy']) None
#
# New Jersey, USA set([]) set([u'jersey']) None
#
# (u'foggia', u'Foggia', 15.55188, 41.45845, u'IT', 137032, u'Europe/Rome') italy
# Foggia, Puglia set([u'foggia']) set([]) set([u'italy'])
#
# (u'dallas', u'Dallas', -96.80667, 32.78306, u'US', 1197816, u'America/Chicago') united states
# dallas, texas set([u'dallas']) set([]) set([u'united states'])
#
# (u'sacramento', u'Sacramento', -121.4944, 38.58157, u'US', 466488, u'America/Los_Angeles') united states
# (u'bay', u'Bay', 121.28554, 14.18368, u'PH', 33547, u'Asia/Manila') philippines
# Greater Sacramento & Bay Area set([u'sacramento', u'bay']) set([]) None
#
# (u'miami', u'Miami', -80.19366, 25.77427, u'US', 399457, u'America/New_York') united states
# Miami, FL set([u'miami']) set([]) set([u'united states'])
#
# United States set([]) set([u'united states']) None
#
# 東京都23 set([]) set([]) None
#
# (u'singapore', u'Singapore', 103.85007, 1.28967, u'SG', 3547809, u'Asia/Singapore') singapore
# Singapore set([u'singapore']) set([u'singapore']) set([u'singapore'])
#
# (u's\xe3o paulo', u'Sao Paulo', -46.63611, -23.5475, u'BR', 10021295, u'America/Sao_Paulo') brazil
# Sao Paulo, Brasil set([u'sao paulo']) set([]) set([u'brazil'])
#
# Planet Earth set([]) set([]) None
#
# Adams set([]) set([]) None
#
# Kun-ei|Pen-High set([]) set([]) None
#
# (u'kansas city', u'Kansas City', -94.57857, 39.09973, u'US', 459787, u'America/Chicago') united states
# Kansas City set([u'kansas city']) set([]) set([u'united states'])
#
# Michigan set([]) set([]) None
#
# Probably skiing set([]) set([]) None
#
# Attadale, Lochcarron, Scotland set([]) set([]) None
#
# (u'paris', u'Paris', -95.55551, 33.66094, u'US', 25171, u'America/Chicago') united states
# Paris - France  set([u'paris']) set([u'france']) set([u'united states'])
#
# (u'portland', u'Portland', -122.67621, 45.52345, u'US', 583776, u'America/Los_Angeles') united states
# Portland, OR set([u'portland']) set([]) set([u'united states'])
#
# Querétaro set([]) set([]) None
#
# California set([]) set([]) None
#
# (u'florence', u'Florence', -111.38734, 33.03145, u'US', 25536, u'America/Phoenix') united states
# Florence set([u'florence']) set([]) set([u'united states'])
#
# (u'cork', u'Cork', -8.47061, 51.89797, u'IE', 190384, u'Europe/Dublin') ireland
# Cork City, Ireland set([u'cork']) set([u'ireland']) set([u'ireland'])
#
# (u'san francisco', u'San Francisco', -122.41942, 37.77493, u'US', 805235, u'America/Los_Angeles') united states
# (u'san', u'San', -4.89562, 13.30335, u'ML', 24811, u'Africa/Bamako') mali
# San Francisco, CA set([u'san francisco', u'san']) set([]) None
#
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Florida set([u'florida']) set([]) set([u'uruguay'])
#
# (u'new york city', u'New York City', -74.00597, 40.71427, u'US', 8175133, u'America/New_York') united states
# New York City, NY set([u'new york city']) set([]) set([u'united states'])
#
# Italia set([]) set([]) None
#
# (u'amsterdam', u'Amsterdam', -74.18819, 42.93869, u'US', 18620, u'America/New_York') united states
# Amsterdam set([u'amsterdam']) set([]) set([u'united states'])
#
# Everywhere set([]) set([]) None
#
# (u'cebu city', u'Cebu City', 123.89071, 10.31672, u'PH', 798634, u'Asia/Manila') philippines
# Cebu City, Philippines set([u'cebu city']) set([u'philippines']) set([u'philippines'])
#
# (u'bristol', u'Bristol', -72.94927, 41.67176, u'US', 60477, u'America/New_York') united states
# Bristol uk set([u'bristol']) set([u'united kingdom']) set([u'united states'])
#
# 日本 千葉 set([]) set([]) None
#
# (u'dubai', u'Dubai', 55.17128, 25.0657, u'AE', 1137347, u'Asia/Dubai') united arab emirates
# Dubai set([u'dubai']) set([]) set([u'united arab emirates'])
#
# (u'ontario', u'Ontario', -117.65089, 34.06334, u'US', 163924, u'America/Los_Angeles') united states
# Ontario, Canada set([u'ontario']) set([u'canada']) set([u'united states'])
#
# (u'singapore', u'Singapore', 103.85007, 1.28967, u'SG', 3547809, u'Asia/Singapore') singapore
# Singapore set([u'singapore']) set([u'singapore']) set([u'singapore'])
#
# 東京都 set([]) set([]) None
#
# จ.ภูเก็ต, ประเทศไทย set([]) set([]) None
#
# (u'east london', u'East London', 27.91162, -33.01529, u'ZA', 478676, u'Africa/Johannesburg') south africa
# (u'croydon', u'Croydon', -0.1, 51.38333, u'GB', 173314, u'Europe/London') united kingdom
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# East London & Croydon set([u'east london', u'croydon', u'london']) set([]) None
#
# Derbyshire set([]) set([]) None
#
# (u'ithaca', u'Ithaca', -76.49661, 42.44063, u'US', 30014, u'America/New_York') united states
# Ithaca, NY set([u'ithaca']) set([]) set([u'united states'])
#
# (u'fray bentos', u'Fray Bentos', -58.30306, -33.12194, u'UY', 23279, u'America/Montevideo') uruguay
# Fray Bentos, Uruguay set([u'fray bentos']) set([u'uruguay']) set([u'uruguay'])
#
# Norge set([]) set([]) None
#
# España set([]) set([]) None
#
# Italia set([]) set([]) None
#
# Magyarország set([]) set([]) None
#
# (u'abu dhabi', u'Abu Dhabi', 54.36667, 24.46667, u'AE', 603492, u'Asia/Dubai') united arab emirates
# (u'\u0101bu', u'Abu', 72.71756, 24.59365, u'IN', 24981, u'Asia/Kolkata') india
# Al Najda St. Abu Dhabi, UAE set([u'abu dhabi', u'abu']) set([]) None
#
# (u'hollywood', u'Hollywood', -118.32674, 34.09834, u'US', 167664, u'America/Los_Angeles') united states
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Hollywood, Florida set([u'hollywood', u'florida']) set([]) None
#
# (u'waterford', u'Waterford', -83.41181, 42.69303, u'US', 75737, u'America/Detroit') united states
#  Dungarvan. Co Waterford set([u'waterford']) set([]) set([u'united states'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London set([u'london']) set([]) set([u'united kingdom'])
#
# (u'everett', u'Everett', -122.20208, 47.97898, u'US', 103019, u'America/Los_Angeles') united states
# Everett set([u'everett']) set([]) set([u'united states'])
#
# Lisboa set([]) set([]) None
#
# Hungary set([]) set([u'hungary']) None
#
# Mad Hatter Adventures set([]) set([]) None
#
# Inglaterra, Reino Unido, set([]) set([]) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles, CA set([u'los angeles']) set([]) set([u'united states'])
#
# Debajo de tu cama 👀  set([]) set([]) None
#
# (u'okinawa', u'Okinawa', 127.80139, 26.33583, u'JP', 125483, u'Asia/Tokyo') japan
# OKINAWA set([u'okinawa']) set([]) set([u'japan'])
#
# NC, NY set([]) set([]) None
#
# (u'rome', u'Rome', -75.45573, 43.21285, u'US', 33725, u'America/New_York') united states
# Rome set([u'rome']) set([]) set([u'united states'])
#
# (u'carolina', u'Carolina', -65.95739, 18.38078, u'PR', 170404, u'America/Puerto_Rico') puerto rico
# North Carolina set([u'carolina']) set([]) set([u'puerto rico'])
#
# (u'portland', u'Portland', -122.67621, 45.52345, u'US', 583776, u'America/Los_Angeles') united states
# Portland, OR set([u'portland']) set([]) set([u'united states'])
#
# (u'plymouth', u'Plymouth', -93.45551, 45.01052, u'US', 70576, u'America/Chicago') united states
# Plymouth, England set([u'plymouth']) set([u'united kingdom']) set([u'united states'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, England set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# (u'atlanta', u'Atlanta', -84.38798, 33.749, u'US', 420003, u'America/New_York') united states
# Atlanta set([u'atlanta']) set([]) set([u'united states'])
#
# Ireland set([]) set([u'ireland']) None
#
# (u'bath', u'Bath', -2.36172, 51.3751, u'GB', 93238, u'Europe/London') united kingdom
# Bath  set([u'bath']) set([]) set([u'united kingdom'])
#
# (u'munich', u'Munich', 11.57549, 48.13743, u'DE', 1260391, u'Europe/Berlin') germany
# Munich, Bavaria set([u'munich']) set([]) set([u'germany'])
#
# (u'dh\u0101ka', u'Dhaka', 85.16698, 26.67479, u'IN', 36111, u'Asia/Kolkata') india
# Dhaka, Bangladesh set([u'dhaka']) set([u'bangladesh']) set([u'india'])
#
# (u'bath', u'Bath', -2.36172, 51.3751, u'GB', 93238, u'Europe/London') united kingdom
# Bath  set([u'bath']) set([]) set([u'united kingdom'])
#
# (u'wiesbaden', u'Wiesbaden', 8.24932, 50.08258, u'DE', 272432, u'Europe/Berlin') germany
# Wiesbaden set([u'wiesbaden']) set([]) set([u'germany'])
#
# (u'new delhi', u'New Delhi', 77.22445, 28.63576, u'IN', 317797, u'Asia/Kolkata') india
# (u'delhi', u'Delhi', 77.23149, 28.65195, u'IN', 10927986, u'Asia/Kolkata') india
# New Delhi set([u'new delhi', u'delhi']) set([]) set([u'india'])
#
# North West, England set([]) set([u'united kingdom']) None
#
# Lisboa set([]) set([]) None
#
# (u'orl\xe9ans', u'Orleans', 1.90389, 47.90289, u'FR', 124149, u'Europe/Paris') france
# (u'new orleans', u'New Orleans', -90.07507, 29.95465, u'US', 343829, u'America/Chicago') united states
# New Orleans, LA set([u'orleans', u'new orleans']) set([]) None
#
# (u'columbia', u'Columbia', -87.03528, 35.61507, u'US', 34681, u'America/Chicago') united states
# (u'vancouver', u'Vancouver', -122.66149, 45.63873, u'US', 161791, u'America/Los_Angeles') united states
# Vancouver, British Columbia set([u'columbia', u'vancouver']) set([]) set([u'united states'])
#
# California, USA set([]) set([]) None
#
# Kingdom of Saudi Arabia set([]) set([u'saudi arabia']) None
#
# (u'radcliffe', u'Radcliffe', -2.32455, 53.56178, u'GB', 34239, u'Europe/London') united kingdom
# Radcliffe On Trent, Notts set([u'radcliffe']) set([]) set([u'united kingdom'])
#
# (u'washington', u'Washington', -113.50829, 37.13054, u'US', 18761, u'America/Denver') united states
# (u'marysville', u'Marysville', -122.17708, 48.05176, u'US', 60020, u'America/Los_Angeles') united states
# Marysville, Washington set([u'washington', u'marysville']) set([]) set([u'united states'])
#
# (u'liverpool', u'Liverpool', -2.97794, 53.41058, u'GB', 468945, u'Europe/London') united kingdom
# Liverpool, UK set([u'liverpool']) set([u'united kingdom']) set([u'united kingdom'])
#
# NJ,CEO,OWN MY COMPANY   set([]) set([]) None
#
# (u'columbia', u'Columbia', -87.03528, 35.61507, u'US', 34681, u'America/Chicago') united states
# (u'vancouver', u'Vancouver', -122.66149, 45.63873, u'US', 161791, u'America/Los_Angeles') united states
# Vancouver, British Columbia set([u'columbia', u'vancouver']) set([]) set([u'united states'])
#
# LA set([]) set([]) None
#
# Bogotá set([]) set([]) None
#
# (u'makati city', u'Makati City', 121.03269, 14.55027, u'PH', 510383, u'Asia/Manila') philippines
# Makati City,  Philippines set([u'makati city']) set([u'philippines']) set([u'philippines'])
#
# (u'chesapeake', u'Chesapeake', -76.27494, 36.81904, u'US', 222209, u'America/New_York') united states
# Chesapeake, VA set([u'chesapeake']) set([]) set([u'united states'])
#
# UK set([]) set([u'united kingdom']) None
#
# (u'florida', u'Florida', -56.21417, -34.09556, u'UY', 32234, u'America/Montevideo') uruguay
# Greater Florida Keys set([u'florida']) set([]) set([u'uruguay'])
#
# 東京都 吉祥寺 無職 set([]) set([]) None
#
# (u'lyon', u'Lyon', 4.84671, 45.74846, u'FR', 472317, u'Europe/Paris') france
# Lyon, France set([u'lyon']) set([u'france']) set([u'france'])
#
# KC MO - In Ya Way set([]) set([]) None
#
# 📍🌎@Foursquare: Femi Abodunde set([]) set([]) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles set([u'los angeles']) set([]) set([u'united states'])
#
# California set([]) set([]) None
#
# PHL  * Ask, Believe, Receive * set([]) set([]) None
#
# TORRELAVEGA-CANTABRIA  set([]) set([]) None
#
# Worldwide set([]) set([]) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles set([u'los angeles']) set([]) set([u'united states'])
#
# United States set([]) set([u'united states']) None
#
# Malaysia set([]) set([u'malaysia']) None
#
# 東京都杉並区高円寺南3-58-22 4.5F set([]) set([]) None
#
# (u'ventura', u'Ventura', -119.29317, 34.27834, u'US', 96769, u'America/Los_Angeles') united states
# Ventura County, CA set([u'ventura']) set([]) set([u'united states'])
#
# UK set([]) set([u'united kingdom']) None
#
# (u'tokyo', u'Tokyo', 139.69171, 35.6895, u'JP', 8336599, u'Asia/Tokyo') japan
# Tokyo set([u'tokyo']) set([]) set([u'japan'])
#
# ...
# Singapore set([u'singapore']) set([u'singapore']) set([u'singapore'])
#
# (u'brooklyn', u'Brooklyn', -73.94958, 40.6501, u'US', 2300664, u'America/New_York') united states
# (u'bay', u'Bay', 121.28554, 14.18368, u'PH', 33547, u'Asia/Manila') philippines
# Bay Ridge, Brooklyn set([u'brooklyn', u'bay']) set([]) None
#
# North of England  set([]) set([u'united kingdom']) None
#
# (u'aalborg', u'Aalborg', 9.9187, 57.048, u'DK', 122219, u'Europe/Copenhagen') denmark
# Aalborg, Danmark set([u'aalborg']) set([]) set([u'denmark'])
#
# (u'berlin', u'Berlin', 13.41053, 52.52437, u'DE', 3426354, u'Europe/Berlin') germany
# Berlin, Deutschland set([u'berlin']) set([]) set([u'germany'])
#
# Discovering new flavors set([]) set([]) None
#
# France set([]) set([u'france']) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London  set([u'london']) set([]) set([u'united kingdom'])
#
# (u'charlotte', u'Charlotte', -80.84313, 35.22709, u'US', 731424, u'America/New_York') united states
# Charlotte, NC set([u'charlotte']) set([]) set([u'united states'])
#
# (u'singapore', u'Singapore', 103.85007, 1.28967, u'SG', 3547809, u'Asia/Singapore') singapore
# Singapore set([u'singapore']) set([u'singapore']) set([u'singapore'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London,Italy,India,Europe,USA  set([u'london']) set([u'india', u'italy']) set([u'united kingdom'])
#
# (u'guadalajara', u'Guadalajara', -103.39182, 20.66682, u'MX', 1640589, u'America/Mexico_City') mexico
# Guadalajara, Jalisco set([u'guadalajara']) set([]) set([u'mexico'])
#
# (u'manchester', u'Manchester', -71.45479, 42.99564, u'US', 109565, u'America/New_York') united states
# Manchester, England set([u'manchester']) set([u'united kingdom']) set([u'united states'])
#
# (u'pittsburgh', u'Pittsburgh', -79.99589, 40.44062, u'US', 305704, u'America/New_York') united states
# Pittsburgh, PA set([u'pittsburgh']) set([]) set([u'united states'])
#
# Milano, Lombardia set([]) set([]) None
#
# (u'dublin', u'Dublin', -121.93579, 37.70215, u'US', 46036, u'America/Los_Angeles') united states
# Dublin City, Ireland set([u'dublin']) set([u'ireland']) set([u'united states'])
#
# (u'bath', u'Bath', -2.36172, 51.3751, u'GB', 93238, u'Europe/London') united kingdom
# Bath set([u'bath']) set([]) set([u'united kingdom'])
#
# https://goo.gl/maps/PDJt2jKny6 set([]) set([]) None
#
# Bruxelles set([]) set([]) None
#
# philippines, tagum set([]) set([u'philippines']) None
#
# (u'sheffield', u'Sheffield', -1.4659, 53.38297, u'GB', 447047, u'Europe/London') united kingdom
# Sheffield, England set([u'sheffield']) set([u'united kingdom']) set([u'united kingdom'])
#
# Living with @kyroskoh (SG) set([]) set([]) None
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles, CA set([u'los angeles']) set([]) set([u'united states'])
#
# malaysia set([]) set([u'malaysia']) None
#
# (u'glasgow', u'Glasgow', -4.25763, 55.86515, u'GB', 610268, u'Europe/London') united kingdom
# Glasgow, Scotland set([u'glasgow']) set([]) set([u'united kingdom'])
#
# (u'cagayan de oro', u'Cagayan de Oro', 124.64722, 8.48222, u'PH', 445103, u'Asia/Manila') philippines
# Cagayan De Oro City set([u'cagayan de oro']) set([]) set([u'philippines'])
#
# IG: taylorleyba set([]) set([]) None
#
# (u'ontario', u'Ontario', -117.65089, 34.06334, u'US', 163924, u'America/Los_Angeles') united states
# Ontario, Canada set([u'ontario']) set([u'canada']) set([u'united states'])
#
# Philippines set([]) set([u'philippines']) None
#
# (u'pittsburgh', u'Pittsburgh', -79.99589, 40.44062, u'US', 305704, u'America/New_York') united states
# Pittsburgh set([u'pittsburgh']) set([]) set([u'united states'])
#
# Alabama set([]) set([]) None
#
# (u'houston', u'Houston', -95.36327, 29.76328, u'US', 2099451, u'America/Chicago') united states
# Houston set([u'houston']) set([]) set([u'united states'])
#
# His Arms ❤️ set([]) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London UK  set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# Arkansas set([]) set([]) None
#
# UK and Spain  set([]) set([u'united kingdom', u'spain']) None
#
# (u'kota bharu', u'Kota Bharu', 102.2386, 6.13328, u'MY', 1459994, u'Asia/Kuala_Lumpur') malaysia
# (u'kot\u0101', u'Kota', 82.02366, 22.29507, u'IN', 15582, u'Asia/Kolkata') india
# Kota Bharu set([u'kota bharu', u'kota']) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London set([u'london']) set([]) set([u'united kingdom'])
#
# (u'tokyo', u'Tokyo', 139.69171, 35.6895, u'JP', 8336599, u'Asia/Tokyo') japan
# (u'nantes', u'Nantes', -1.55336, 47.21725, u'FR', 277269, u'Europe/Paris') france
# Nantes & Tokyo set([u'tokyo', u'nantes']) set([]) None
#
# Wherever there is good food! set([]) set([]) None
#
# (u'metro', u'Metro', 105.30667, -5.11306, u'ID', 149526, u'Asia/Jakarta') indonesia
# Weichert, Realtors®-Team Metro set([u'metro']) set([]) set([u'indonesia'])
#
# (u'sendai', u'Sendai', 140.86667, 38.26667, u'JP', 1063103, u'Asia/Tokyo') japan
# Sendai JAPAN set([u'sendai']) set([u'japan']) set([u'japan'])
#
# The World set([]) set([]) None
#
# WL102 set([]) set([]) None
#
# United States set([]) set([u'united states']) None
#
# (u'blackburn', u'Blackburn', -2.48333, 53.75, u'GB', 106154, u'Europe/London') united kingdom
# Blackburn, England set([u'blackburn']) set([u'united kingdom']) set([u'united kingdom'])
#
# Pennsylvania, USA set([]) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, England set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# CTBA/PR set([]) set([]) None
#
# République du Bénin set([]) set([]) None
#
# Worldwide set([]) set([]) None
#
# Milano, Lombardia set([]) set([]) None
#
# Canada set([]) set([u'canada']) None
#
# Via Ripamonti 9, Milano set([]) set([]) None
#
# (u'reno', u'Reno', -119.8138, 39.52963, u'US', 225221, u'America/Los_Angeles') united states
# Reno, NV set([u'reno']) set([]) set([u'united states'])
#
# (u'essex', u'Essex', -76.47496, 39.30927, u'US', 39262, u'America/New_York') united states
# Essex set([u'essex']) set([]) set([u'united states'])
#
# Direccion creativa set([]) set([]) None
#
# Canadian Rockies set([]) set([]) None
#
# (u'toronto', u'Toronto', -79.4163, 43.70011, u'CA', 2600000, u'America/Toronto') canada
# TORONTO set([u'toronto']) set([]) set([u'canada'])
#
# 747 9th Ave set([]) set([]) None
#
# USA - Spain set([]) set([u'spain']) None
#
# (u'kota kinabalu', u'Kota Kinabalu', 116.0724, 5.9749, u'MY', 457326, u'Asia/Kuching') malaysia
# (u'kot\u0101', u'Kota', 82.02366, 22.29507, u'IN', 15582, u'Asia/Kolkata') india
# Kota Kinabalu set([u'kota kinabalu', u'kota']) set([]) None
#
# Buford, GA set([]) set([]) None
#
# India set([]) set([u'india']) None
#
# New York set([]) set([]) None
#
# (u'nairobi', u'Nairobi', 36.81667, -1.28333, u'KE', 2750547, u'Africa/Nairobi') kenya
# Nairobi set([u'nairobi']) set([]) set([u'kenya'])
#
# (u'tulsa', u'Tulsa', -95.99277, 36.15398, u'US', 391906, u'America/Chicago') united states
# 1621 E. 11th St. Tulsa set([u'tulsa']) set([]) set([u'united states'])
#
# Killingworth, CT. U.S.A. set([]) set([]) None
#
# Downingtown, PA set([]) set([]) None
#
# 愛知県小牧市 set([]) set([]) None
#
# Νorth greece zip 64100  set([]) set([u'greece']) None
#
# India set([]) set([u'india']) None
#
# (u'highland', u'Highland', -111.79447, 40.42548, u'US', 15523, u'America/Denver') united states
# Highland, CA set([u'highland']) set([]) set([u'united states'])
#
# https://goo.gl/maps/PDJt2jKny6 set([]) set([]) None
#
# (u'z\xfcrich', u'Zurich', 8.55, 47.36667, u'CH', 341730, u'Europe/Zurich') switzerland
# Zurich set([u'zurich']) set([]) set([u'switzerland'])
#
# Milano set([]) set([]) None
#
# (u'winter park', u'Winter Park', -81.33924, 28.6, u'US', 27852, u'America/New_York') united states
# Winter Park, FL set([u'winter park']) set([]) set([u'united states'])
#
# (u'mexico', u'Mexico', 120.7198, 15.0646, u'PH', 43694, u'Asia/Manila') philippines
# Mexico, D.F. set([u'mexico']) set([u'mexico']) set([u'philippines'])
#
# (u'chicago', u'Chicago', -87.65005, 41.85003, u'US', 2695598, u'America/Chicago') united states
# Chicago, IL set([u'chicago']) set([]) set([u'united states'])
#
# Earth Watching Rap Battles  set([]) set([]) None
#
# Israel set([]) set([u'israel']) None
#
# (u'altadena', u'Altadena', -118.13118, 34.18973, u'US', 42777, u'America/Los_Angeles') united states
# Altadena Woods set([u'altadena']) set([]) set([u'united states'])
#
# Alabama, USA set([]) set([]) None
#
# in Mogul land  set([]) set([]) None
#
# (u'cambridge', u'Cambridge', -71.10561, 42.3751, u'US', 105162, u'America/New_York') united states
# Cambridge, England set([u'cambridge']) set([u'united kingdom']) set([u'united states'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London set([u'london']) set([]) set([u'united kingdom'])
#
# interweb set([]) set([]) None
#
# United States set([]) set([u'united states']) None
#
# São Paulo / Brasil set([]) set([]) None
#
# (u'bucharest', u'Bucharest', 26.10626, 44.43225, u'RO', 1877155, u'Europe/Bucharest') romania
# BUCHAREST set([u'bucharest']) set([]) set([u'romania'])
#
# (u'toronto', u'Toronto', -79.4163, 43.70011, u'CA', 2600000, u'America/Toronto') canada
# Toronto set([u'toronto']) set([]) set([u'canada'])
#
# Malaysia set([]) set([u'malaysia']) None
#
# (u'colorado', u'Colorado', -51.97306, -22.8375, u'BR', 20449, u'America/Sao_Paulo') brazil
# (u'denver', u'Denver', -104.9847, 39.73915, u'US', 600158, u'America/Denver') united states
# Denver Colorado set([u'colorado', u'denver']) set([]) None
#
# (u'medan', u'Medan', 98.66667, 3.58333, u'ID', 1750971, u'Asia/Jakarta') indonesia
# Medan, indonesia set([u'medan']) set([u'indonesia']) set([u'indonesia'])
#
# (u'banbury', u'Banbury', -1.34222, 52.0632, u'GB', 46075, u'Europe/London') united kingdom
# Banbury set([u'banbury']) set([]) set([u'united kingdom'])
#
# NYC set([]) set([]) None
#
# Agricola set([]) set([]) None
#
# (u'las vegas', u'Las Vegas', -115.13722, 36.17497, u'US', 583756, u'America/Los_Angeles') united states
# Las Vegas, NV set([u'las vegas']) set([]) set([u'united states'])
#
# Montbeugny, France set([]) set([u'france']) None
#
# (u'copenhagen', u'Copenhagen', 12.56553, 55.67594, u'DK', 1153615, u'Europe/Copenhagen') denmark
# Copenhagen, Denmark set([u'copenhagen']) set([u'denmark']) set([u'denmark'])
#
# Milano, Lombardia set([]) set([]) None
#
# Córdoba, Spain set([]) set([u'spain']) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London set([u'london']) set([]) set([u'united kingdom'])
#
# (u'hyderabad', u'Hyderabad', 68.37366, 25.39242, u'PK', 1386330, u'Asia/Karachi') pakistan
# Hyderabad, India set([u'hyderabad']) set([u'india']) set([u'pakistan'])
#
# Fiume Veneto set([]) set([]) None
#
# (u'birmingham', u'Birmingham', -83.21132, 42.5467, u'US', 20103, u'America/Detroit') united states
# Birmingham, England set([u'birmingham']) set([u'united kingdom']) set([u'united states'])
#
# (u'barueri', u'Barueri', -46.87611, -23.51056, u'BR', 251994, u'America/Sao_Paulo') brazil
# Barueri, SP, Brasil set([u'barueri']) set([]) set([u'brazil'])
#
# LA  set([]) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, England set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# Australia set([]) set([u'australia']) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, England set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# https://goo.gl/maps/PDJt2jKny6 set([]) set([]) None
#
# Milky Way set([]) set([]) None
#
# Pacific Northwest set([]) set([]) None
#
# planet earth set([]) set([]) None
#
# (u'akron', u'Akron', -81.51901, 41.08144, u'US', 199110, u'America/New_York') united states
# Akron set([u'akron']) set([]) set([u'united states'])
#
# 3764 E Tremont Ave Bx, Ny set([]) set([]) None
#
# (u'sydney', u'Sydney', -60.1831, 46.1351, u'CA', 105968, u'America/Glace_Bay') canada
# sydney set([u'sydney']) set([]) set([u'canada'])
#
# Нижний Новгород set([]) set([]) None
#
# (u'moscow', u'Moscow', -117.00017, 46.73239, u'US', 23800, u'America/Los_Angeles') united states
# Moscow, Russia set([u'moscow']) set([u'russia']) set([u'united states'])
#
# (u'cincinnati', u'Cincinnati', -84.45689, 39.162, u'US', 296943, u'America/New_York') united states
# Cincinnati,OH & Palm Beach,FL  set([u'cincinnati']) set([]) set([u'united states'])
#
# (u'dubai', u'Dubai', 55.17128, 25.0657, u'AE', 1137347, u'Asia/Dubai') united arab emirates
# Dubai set([u'dubai']) set([]) set([u'united arab emirates'])
#
# Mars set([]) set([]) None
#
# (u'chapel hill', u'Chapel Hill', -79.05584, 35.9132, u'US', 57233, u'America/New_York') united states
# Chapel Hill, NC set([u'chapel hill']) set([]) set([u'united states'])
#
# (u'naga', u'Naga', 123.758, 10.20898, u'PH', 28571, u'Asia/Manila') philippines
# Naga City set([u'naga']) set([]) set([u'philippines'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# (u'bexley', u'Bexley', 0.14866, 51.44162, u'GB', 228000, u'Europe/London') united kingdom
# Bexley, London set([u'london', u'bexley']) set([]) set([u'united kingdom'])
#
# (u'ravenna', u'Ravenna', 12.20121, 44.41344, u'IT', 80868, u'Europe/Rome') italy
# Ravenna set([u'ravenna']) set([]) set([u'italy'])
#
# Sud-Ouest ☀️🏖️🌊🐟🦑🌶️🍇🍷🌲 set([]) set([]) None
#
# Köln set([]) set([]) None
#
# (u'sheffield', u'Sheffield', -1.4659, 53.38297, u'GB', 447047, u'Europe/London') united kingdom
# Sheffield, England set([u'sheffield']) set([u'united kingdom']) set([u'united kingdom'])
#
# 風の吹く場所。 set([]) set([]) None
#
# Kitchen set([]) set([]) None
#
# The World set([]) set([]) None
#
# (u'liverpool', u'Liverpool', -2.97794, 53.41058, u'GB', 468945, u'Europe/London') united kingdom
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# Liverpool/London set([u'liverpool', u'london']) set([]) set([u'united kingdom'])
#
# (u'paris', u'Paris', -95.55551, 33.66094, u'US', 25171, u'America/Chicago') united states
# Paris france set([u'paris']) set([u'france']) set([u'united states'])
#
# East Anglia set([]) set([]) None
#
# Hawaii, USA set([]) set([]) None
#
# (u'palermo', u'Palermo', 13.33561, 38.13205, u'IT', 648260, u'Europe/Rome') italy
# Arenales 3350, Palermo. CABA set([u'palermo']) set([]) set([u'italy'])
#
# (u'tokyo', u'Tokyo', 139.69171, 35.6895, u'JP', 8336599, u'Asia/Tokyo') japan
# Tokyo set([u'tokyo']) set([]) set([u'japan'])
#
# Vegas, USA set([]) set([]) None
#
# (u'glasgow', u'Glasgow', -4.25763, 55.86515, u'GB', 610268, u'Europe/London') united kingdom
# (u'carolina', u'Carolina', -65.95739, 18.38078, u'PR', 170404, u'America/Puerto_Rico') puerto rico
# california//carolina//glasgow set([u'glasgow', u'carolina']) set([]) None
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, UK (EU Remainer) set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# (u'mexico', u'Mexico', 120.7198, 15.0646, u'PH', 43694, u'Asia/Manila') philippines
# Mexico, DF  set([u'mexico']) set([u'mexico']) set([u'philippines'])
#
# ＊あおもーり set([]) set([]) None
#
# (u'kyoto', u'Kyoto', 135.75385, 35.02107, u'JP', 1459640, u'Asia/Tokyo') japan
# (u'tokyo', u'Tokyo', 139.69171, 35.6895, u'JP', 8336599, u'Asia/Tokyo') japan
# JAPAN,KYOTO,TOKYO set([u'kyoto', u'tokyo']) set([u'japan']) set([u'japan'])
#
# (u'los angeles', u'Los Angeles', -118.24368, 34.05223, u'US', 3792621, u'America/Los_Angeles') united states
# Los Angeles, set([u'los angeles']) set([]) set([u'united states'])
#
# Hellas-Verona  set([]) set([]) None
#
# (u'calgary', u'Calgary', -114.08529, 51.05011, u'CA', 1019942, u'America/Edmonton') canada
# Calgary, Alberta set([u'calgary']) set([]) set([u'canada'])
#
# (u'london', u'London', -0.12574, 51.50853, u'GB', 7556900, u'Europe/London') united kingdom
# London, England set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
#
# (u'luxembourg', u'Luxembourg', 6.13, 49.61167, u'LU', 76684, u'Europe/Luxembourg') luxembourg
# Luxembourg set([u'luxembourg']) set([u'luxembourg']) set([u'luxembourg'])
