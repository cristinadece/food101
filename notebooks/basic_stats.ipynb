# %% [markdown]
# # Basic Stats

# %%
# Raw tweets from streaming: /data/muntean/food-tweets
# Wordcount per day and whole (4-grams): /home/muntean/food-wordcount
import os
import sys
from collections import defaultdict
os.chdir("/Users/muntean/Documents/workspace/food101/")
# from twitter.Tweet import Tweet

# %% [markdown]
# ## Processing

# %% [markdown]
# ### Simple counts

# %%
tweetsAsDict = Tweet.getTweetAsDictionary("/Users/muntean/food-tweets/")

countTweets = 0
countCoords = 0
countPlace = 0
countUserLocation = 0
countImage = 0
countMedia =0 
for tweet, fileName in tweetsAsDict:
    if tweet["coordinates"] is not None:
        countCoords +=1
    if tweet["place"] is not None:
        countPlace +=1
    if tweet['user']['location'] is not None:
        countUserLocation +=1
    # we have two situations: either media is attached to the tweet or we have a link to instagram
    if "media" in tweet["entities"]:
        countMedia +=1
        foundMedia = tweet["entities"]["media"]
        # the type can be photo, video ...
        if foundMedia[0]["type"] == "photo":
            countImage += 1
    countTweets +=1

# %% [markdown]
# ### Intersections with tweets attributes

# %%
def getLocationData(tweet):
    """
    These can always have None values; e.g no coordinates, no city, no user location
    :param tweet:
    :return:
    """
    if tweet["coordinates"] is not None:
        tweet_coords = tweet['coordinates']['coordinates']  # returns a list [longitude, latitude]
    else:
        tweet_coords = None

    if tweet["place"] is not None:
        if tweet["place"]["place_type"] == "city":
            tweet_place_city = tweet["place"]["name"]  # if place type == city
            tweet_place_country = tweet["place"]["country"]
            tweet_place_country_code = tweet["place"]["country_code"]
        else:
            tweet_place_city = None
            tweet_place_country = tweet["place"]["country"]
            tweet_place_country_code = tweet["place"]["country_code"]
    else:
        tweet_place_city = None
        tweet_place_country = None
        tweet_place_country_code = None

    user_location = tweet['user']['location']

    return tweet_coords, tweet_place_city, tweet_place_country, tweet_place_country_code, user_location

# %%
tweetsAsDict = Tweet.getTweetAsDictionary("/Users/muntean/food-tweets")

dictCoords = defaultdict()
dictPlace = defaultdict()
dictUserLocation = defaultdict()
dictImage = defaultdict()

for tweet, fileName in tweetsAsDict:
    tweet_coords, tweet_place_city, tweet_place_country, tweet_place_country_code, user_location = getLocationData(tweet)
    if tweet_coords is not None:
        dictCoords[tweet["id_str"]] = tweet_coords
    if tweet_place_country_code is not None:
        dictPlace[tweet["id_str"]] = tweet_place_country # or country code or even city but may be less
    if user_location is not None:
        dictUserLocation[tweet["id_str"]] = user_location 
    if "media" in tweet["entities"]:
        foundMedia = tweet["entities"]["media"]
        dictImage[tweet["id_str"]] = foundMedia[0]["media_url"]

# %% [markdown]
# ## Atributes

# %% [markdown]
# ### 1. How many tweets in total?

# %%
# Food related tweets (filtered on relevant kw matching #food): 
print "Total Tweets: ", countTweets
# Out:
# Total Tweets:  69808

# %% [markdown]
# ### 2. How many tweets with Place or GEO? How many with valid user location?

# %%
# Tweets with Place, Geo and User location
print "Tweets with Coords: ", countCoords
print "Tweets with Place: ", countPlace
print "Tweets with User Location: ", countUserLocation
# Out:
# Tweets with Coords:  4801
# Tweets with Place:  6242
# Tweets with User Location:  49621

# %% [markdown]
# ### 3. How many tweets with image?

# %%
# Tweets with images or other media
print "Tweets with Image: ", countImage, " all media: ", countMedia
# Out:
# Tweets with Image:  18234  all media:  18234

# %% [markdown]
# ### 4. How many with combinations of all of the above?

# %%
# How many with coords and images
a = set(dictCoords.keys()).intersection(dictImage.keys())
print len(a)
# How many with Country code and images
b = set(dictPlace.keys()).intersection(dictImage.keys())
print len(b)
# How many with user location and images
c = set(dictUserLocation.keys()).intersection(dictImage.keys())
print len(c)


# print dictCoords["673842284794765312"]
# print dictPlace["673842284794765312"]
# print dictImage["673842284794765312"]
# Out:
# 52
# 643
# 11961

# %% [markdown]
# ## Distribution by countries

# %%
reversed_dictPlace = defaultdict(list)
for key,value in dictPlace.iteritems():
    reversed_dictPlace[value].append(key)
print "Total countries", len(reversed_dictPlace) 

#order dict per popularity
for k in sorted(reversed_dictPlace, key=lambda k: len(reversed_dictPlace[k]), reverse=True):
        print k, len(reversed_dictPlace[k])

# %%
### only for the ones with country and photo
reversed_b = defaultdict(list)
for tweetID in b:
    reversed_b[dictPlace[tweetID]].append(tweetID)
print "Total countries", len(reversed_b) 

#order dict per popularity
for k in sorted(reversed_b, key=lambda k: len(reversed_b[k]), reverse=True):
        print k, len(reversed_b[k])

# %% [markdown]
# ## Visualize wordcount

# %%
# better look on the server

# %% [markdown]
# ## Test user location field for 1000

# %%
def getLocationsFromToken(token, citiesIndex, citiesInfo, countriesIndex, countriesInfo):
    """
    
    :param token: 
    :param citiesIndex: 
    :param citiesInfo: 
    :param countriesIndex: 
    :param countriesInfo: 
    :return: 
    """
    city = ""
    country = ""

    if citiesIndex[token]: #TODO: this condition is because we have more cities with same name
        geonamesidCity = citiesIndex[token][0]
        city = citiesInfo[geonamesidCity][0]
#         print "<-------- get City from token -------->"
#         print "token: ", token
#         print "list of geonameids in index:", citiesIndex[token]
#         print "geonameid first in list:", citiesIndex[token][0]
#         print "city: ", citiesInfo[citiesIndex[token][0]]
#         print "<---------------------------------->"
        
    if countriesIndex[token]:
        geonamesidCountry = countriesIndex[token][0]
        country = countriesInfo[geonamesidCountry][0]  # we take the name of the country from the tuple, elim. both UK and United K.
#         print "<-------- get Country from token -------->"
#         print "token: ", token
#         print "list of geonameids in index:", countriesIndex[token][0]
#         print "geonameid first in list:", countriesIndex[token][0]
#         print "country: ", countriesInfo[countriesIndex[token][0]]
#         print "<---------------------------------->"
    return city, country



def cleanLists(potentialCities, potentialCountries):
    if "" in potentialCities:
        potentialCities.remove("")
    if "" in potentialCountries:
        potentialCountries.remove("")
    return potentialCities, potentialCountries

# %%
def inferCountryFromCity(citiesList, citiesIndex, citiesInfo, ccDict):
    """
    This should be done by country code crossing
    :param citiesList: 
    :param cityDict: 
    :param ccDict: 
    :return: 
    """

    potential_countries = set()
    for city in citiesList:
        geonameidCity = citiesIndex[city.lower()][0]  # TODO: this is tricky, we might have more cities with same name
        country_code = citiesInfo[geonameidCity][4]
        potential_countries.add(ccDict[country_code])
    return potential_countries

# %%
from tokenizer import twokenize, ngrams
def getUserLocation(locationField, citiesIndex, citiesInfo, countriesIndex, countriesInfo):
    """
    THis field is an empty string
    :param tweet:
    :return:
    """

    potentialCities = set()
    potentialCountries = set()

    # 1. split by / - the only char that is not in the tokenizer!
    if "/" in locationField:
        locArray = locationField.split("/")
        for token in locArray:
            city, country = getLocationsFromToken(token.strip().lower(), citiesIndex, citiesInfo, countriesIndex, countriesInfo)
            if city or country:
                potentialCities.add(city)
                potentialCountries.add(country)

    if "," in locationField:
        locArray = locationField.split(",")
        for token in locArray:
            city, country = getLocationsFromToken(token.strip().lower(), citiesIndex, citiesInfo, countriesIndex, countriesInfo)
            if city or country:
                potentialCities.add(city)
                potentialCountries.add(country)

    # 2. tokenize with util and get unigrams, bigrams and trigrams - to lower
    # unigrams
    tokenList = twokenize.tokenize(locationField.lower())
    tokens = ngrams.window_no_twitter_elems(tokenList, 1)
    for token in tokens:
        city, country = getLocationsFromToken(token.strip(), citiesIndex, citiesInfo, countriesIndex, countriesInfo)
        if city or country:
            potentialCities.add(city)
            potentialCountries.add(country)

    # bigrams
    tokens = ngrams.window_no_twitter_elems(tokenList, 2)
    for token in tokens:
        city, country = getLocationsFromToken(token.strip(), citiesIndex, citiesInfo, countriesIndex, countriesInfo)
        if city or country:
            potentialCities.add(city)
            potentialCountries.add(country)

    # trigrams
    tokens = ngrams.window_no_twitter_elems(tokenList, 3)
    for token in tokens:
        city, country = getLocationsFromToken(token, citiesIndex, citiesInfo, countriesIndex, countriesInfo)
        if city or country:
            potentialCities.add(city)
            potentialCountries.add(country)

    cities, countries = cleanLists(potentialCities, potentialCountries)
    return cities, countries

# %%
def getFinalUserLocation(user_cities, user_countries, inferred_countries):
    city = ""
    country = ""
    if len(user_cities) == 1:
        city = next(iter(user_cities))

    if len(user_countries) == 1 and len(inferred_countries) == 1:
        country = next(iter(user_countries))

    if len(user_countries) == 1 and len(inferred_countries) == 0:
        country = next(iter(user_countries))

    if len(user_countries) == 0 and len(inferred_countries) == 1:
        country = next(iter(inferred_countries))
        
    # this means we have a city and ambiguous country tagging, 
    # but since we can't infer country we must dismiss city
    if len(city) > 0 and len(country) == 0:
        city = ""

    return city, country

# %%
from location import locations
import location.get_place_from_user_location 

citiesIndex, citiesInfo = locations.Cities.loadFromFile()
countriesIndex, countriesInfo = locations.Countries.loadFromFile()
ccDict = locations.Countries.countryCodeDict(countriesInfo)

i = 0
for tweet_id, user_loc in dictUserLocation.iteritems():
    i += 1
    print
    print user_loc
    user_cities, user_countries = getUserLocation(user_loc, citiesIndex, citiesInfo, countriesIndex, countriesInfo)
    inferred_countries = inferCountryFromCity(user_cities, citiesIndex, citiesInfo, ccDict)
    
    for city in user_cities:
        geonameidCity = citiesIndex[city.lower()][0] # this is a list
        #print citiesInfo[geonameidCity], ccDict[citiesInfo[geonameidCity][4]]
    print user_cities, user_countries, inferred_countries   
    city, country = getFinalUserLocation(user_cities, user_countries, inferred_countries)
    print city, country
    if i % 1000 == 0:
        break
# Out:
# All cities with all name:  22310
# All cities unique geonameid:   23516
# All countries with all names:  24782
# All countries unique geonameid:   251
# Len of country code dict 251
#
# Johannesburg, South Africa
# set([u'johannesburg']) set([u'south africa']) set([u'south africa'])
# johannesburg south africa
#
# UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Southend
# set([]) set([]) set([])
#
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# everywhere
# set([]) set([]) set([])
#
#
# Madrid, España
# set([u'madrid']) set([u'spain']) set([u'spain'])
# madrid spain
#
# Bolton Abbey, Skipton
# set([u'bolton']) set([]) set([u'united kingdom'])
# bolton united kingdom
#
# Ventura, CA
# set([u'ventura']) set([]) set([u'united states'])
# ventura united states
#
#  North Sioux City, SD.
# set([u'sioux city']) set([]) set([u'united states'])
# sioux city united states
#
# Brighton, England
# set([u'brighton']) set([u'united kingdom']) set([u'united kingdom'])
# brighton united kingdom
#
# California
# set([]) set([]) set([])
#
#
# Philippines
# set([]) set([u'philippines']) set([])
#  philippines
#
# Roma, Lazio
# set([u'rome']) set([]) set([u'italy'])
# rome italy
#
# California, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Las Vegas NV
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# Manchester Withington
# set([u'manchester']) set([]) set([u'united kingdom'])
# manchester united kingdom
#
# Hogwarts
# set([]) set([]) set([])
#
#
# Ohio, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Wherever Dilip Is
# set([]) set([]) set([])
#
#
# Belleville, Illinois
# set([u'belleville']) set([]) set([u'canada'])
# belleville canada
#
# New York
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Scranton, Pa
# set([u'scranton']) set([]) set([u'united states'])
# scranton united states
#
# Stillwater MN
# set([u'stillwater']) set([]) set([u'united states'])
# stillwater united states
#
# Nueva York, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Addison
# set([u'addison']) set([]) set([u'united states'])
# addison united states
#
# Kennesaw, GA
# set([u'kennesaw']) set([]) set([u'united states'])
# kennesaw united states
#
# The Best Side of Columbus
# set([u'columbus']) set([]) set([u'united states'])
# columbus united states
#
# Milano, Lombardia
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# The Bakery
# set([]) set([]) set([])
#
#
# Wherever the plane lands
# set([]) set([]) set([])
#
#
# Manchester
# set([u'manchester']) set([]) set([u'united kingdom'])
# manchester united kingdom
#
# New Zealand (NZ)
# set([]) set([u'new zealand']) set([])
#  new zealand
#
# London United Kingdom
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Raleigh Durham Chapel Hill
# set([u'chapel hill', u'durham', u'raleigh']) set([]) set([u'united states'])
#  united states
#
# Sydney, Australia
# set([u'sydney']) set([u'australia']) set([u'australia'])
# sydney australia
#
# Atlanta
# set([u'atlanta']) set([]) set([u'united states'])
# atlanta united states
#
# Butuan City, Philippines
# set([u'butuan']) set([u'philippines']) set([u'philippines'])
# butuan philippines
#
# California, USA
# set([]) set([u'united states']) set([])
#  united states
#
# los angeles
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# California, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Florence, AL
# set([u'florence']) set([]) set([u'italy'])
# florence italy
#
# South East England
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Independence
# set([u'independence']) set([]) set([u'united states'])
# independence united states
#
# Bromley, London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# LA, NYC, Chicago, D.C., Vegas
# set([u'new york city', u'chicago']) set([]) set([u'united states'])
#  united states
#
# Homestead, FL
# set([u'homestead']) set([]) set([u'united states'])
# homestead united states
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# World
# set([]) set([]) set([])
#
#
# Las Vegas, NV
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# Washington
# set([u'washington']) set([]) set([u'united kingdom'])
# washington united kingdom
#
# Bengaluru, Karnataka
# set([u'bengaluru']) set([]) set([u'india'])
# bengaluru india
#
# Mar del plata Argentina
# set([u'mar del plata']) set([u'argentina']) set([u'argentina'])
# mar del plata argentina
#
# Parma
# set([u'parma']) set([]) set([u'italy'])
# parma italy
#
# Discovering new flavors
# set([]) set([]) set([])
#
#
# Worldwide
# set([]) set([]) set([])
#
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# Harrisonburg, VA
# set([u'harrisonburg']) set([]) set([u'united states'])
# harrisonburg united states
#
# Universe
# set([]) set([]) set([])
#
#
# Seattle, WA
# set([u'seattle']) set([]) set([u'united states'])
# seattle united states
#
# sul tatami
# set([]) set([]) set([])
#
#
# Sheffield, England
# set([u'sheffield']) set([u'united kingdom']) set([u'united kingdom'])
# sheffield united kingdom
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# 韓ヲタ
# set([]) set([]) set([])
#
#
# Cairo/Egypt
# set([u'cairo']) set([u'egypt']) set([u'egypt'])
# cairo egypt
#
# 38.593099,-90.331922
# set([]) set([]) set([])
#
#
# Oxford
# set([u'oxford']) set([]) set([u'united kingdom'])
# oxford united kingdom
#
# Dublin, International
# set([u'dublin']) set([]) set([u'ireland'])
# dublin ireland
#
# Studio City, Los Angeles
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# England, United Kingdom
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Ｔｏｋｙｏ　toka
# set([]) set([]) set([])
#
#
# Hauts-de-Seine, Ile-de-France
# set([]) set([]) set([])
#
#
# CABA
# set([]) set([]) set([])
#
#
# Lyon France
# set([u'lyon']) set([u'france']) set([u'france'])
# lyon france
#
# New Westminster, BC
# set([u'westminster', u'new westminster']) set([]) set([u'united states', u'canada'])
#
#
# Barcelona
# set([u'barcelona']) set([]) set([u'spain'])
# barcelona spain
#
# l'aquila
# set([u"l'aquila"]) set([]) set([u'italy'])
# l'aquila italy
#
# Iceland
# set([]) set([u'iceland']) set([])
#  iceland
#
# Hale, Cheshire
# set([u'cheshire', u'hale']) set([]) set([u'united states', u'united kingdom'])
#
#
# الدوحة, دولة قطر
# set([]) set([u'qatar']) set([])
#  qatar
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Chicago
# set([u'chicago']) set([]) set([u'united states'])
# chicago united states
#
# Helsinki, Finland
# set([u'helsinki']) set([u'finland']) set([u'finland'])
# helsinki finland
#
# Liverpool
# set([u'liverpool']) set([]) set([u'united kingdom'])
# liverpool united kingdom
#
# Las Vegas, Nevada
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# Θεσσαλονίκη, Ελλάς
# set([]) set([u'greece']) set([])
#  greece
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# Саратов
# set([]) set([]) set([])
#
#
# Flovilla Georgia US 30216-2105
# set([]) set([u'georgia']) set([])
#  georgia
#
# blackpool
# set([u'blackpool']) set([]) set([u'united kingdom'])
# blackpool united kingdom
#
# Salt Lake City, UT
# set([u'salt lake city']) set([]) set([u'united states'])
# salt lake city united states
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# Barcelona, Gracia
# set([u'barcelona']) set([]) set([u'spain'])
# barcelona spain
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# Cornwall
# set([u'cornwall']) set([]) set([u'canada'])
# cornwall canada
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# San Diego, CA
# set([u'san diego']) set([]) set([u'united states'])
# san diego united states
#
# England, UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Earth
# set([]) set([]) set([])
#
#
# France
# set([]) set([u'france']) set([])
#  france
#
# Worldwide
# set([]) set([]) set([])
#
#
# Darmstadt, Germany
# set([u'darmstadt']) set([u'germany']) set([u'germany'])
# darmstadt germany
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Duque Ahumada 14.Pso maritimo
# set([]) set([]) set([])
#
#
# New Jersey, USA
# set([]) set([u'united states']) set([])
#  united states
#
# デリッシュキッチン DELISHKITCHEN
# set([]) set([]) set([])
#
#
# Penzance, England
# set([u'penzance']) set([u'united kingdom']) set([u'united kingdom'])
# penzance united kingdom
#
# Roma
# set([u'rome']) set([]) set([u'italy'])
# rome italy
#
# Northern France / Belgium
# set([]) set([u'belgium', u'france']) set([])
#
#
# swansea
# set([u'swansea']) set([]) set([u'united kingdom'])
# swansea united kingdom
#
# Boca Raton, Fl
# set([u'boca raton']) set([]) set([u'united states'])
# boca raton united states
#
# San Antonio, Texas
# set([u'san antonio']) set([]) set([u'united states'])
# san antonio united states
#
# USA
# set([]) set([u'united states']) set([])
#  united states
#
# Madison WI, USA
# set([u'madison']) set([u'united states']) set([u'united states'])
# madison united states
#
# Florence, AL
# set([u'florence']) set([]) set([u'italy'])
# florence italy
#
# Seattle, WA
# set([u'seattle']) set([]) set([u'united states'])
# seattle united states
#
# Grayson Allen is a douche bag
# set([]) set([]) set([])
#
#
# Charlotte, NC
# set([u'charlotte']) set([]) set([u'united states'])
# charlotte united states
#
# Hanwell, London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# Living with @kyroskoh (SG)
# set([]) set([]) set([])
#
#
# Oman
# set([]) set([u'oman']) set([])
#  oman
#
# León, Guanajuato
# set([u'le\xf3n', u'guanajuato']) set([]) set([u'nicaragua', u'mexico'])
#
#
# Chez Jawad
# set([]) set([]) set([])
#
#
# Miami, Florida USA
# set([u'miami']) set([u'united states']) set([u'united states'])
# miami united states
#
# Everywhere : (17+16=)33 & 237
# set([]) set([]) set([])
#
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Boadilla del Monte
# set([u'boadilla del monte']) set([]) set([u'spain'])
# boadilla del monte spain
#
# Birmingham/Muscle Shoals
# set([u'birmingham']) set([]) set([u'united kingdom'])
# birmingham united kingdom
#
# Homestead, FL
# set([u'homestead']) set([]) set([u'united states'])
# homestead united states
#
# TheWorld- Houston,Tx.,U.S.A.
# set([u'houston']) set([u'united states']) set([u'united states'])
# houston united states
#
# Cedar Rapids, IA
# set([u'cedar rapids']) set([]) set([u'united states'])
# cedar rapids united states
#
# Chester
# set([u'chester']) set([]) set([u'united kingdom'])
# chester united kingdom
#
# Chippenham, Wiltshire
# set([u'chippenham']) set([]) set([u'united kingdom'])
# chippenham united kingdom
#
# Battle Creek, MI
# set([u'battle creek']) set([]) set([u'united states'])
# battle creek united states
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Biggleswade, England
# set([u'biggleswade']) set([u'united kingdom']) set([u'united kingdom'])
# biggleswade united kingdom
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# Long Beach, CA
# set([u'long beach']) set([]) set([u'united states'])
# long beach united states
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Illinois, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Charlotte, NC
# set([u'charlotte']) set([]) set([u'united states'])
# charlotte united states
#
# Honolulu, HI
# set([u'honolulu']) set([]) set([u'united states'])
# honolulu united states
#
# Comunidad Valenciana, España
# set([]) set([u'spain']) set([])
#  spain
#
# 390-392 Promenade, Blackpool.
# set([u'blackpool']) set([]) set([u'united kingdom'])
# blackpool united kingdom
#
# USA|EUROPE|ASIA|GLOBAL✈️
# set([]) set([]) set([])
#
#
# Living with @kyroskoh (SG)
# set([]) set([]) set([])
#
#
# ‍19 ‍さい    福岡こども
# set([]) set([]) set([])
#
#
# Hamilton, Ontario
# set([u'ontario', u'hamilton']) set([]) set([u'united states', u'canada'])
#
#
# Ottawa
# set([u'ottawa']) set([]) set([u'canada'])
# ottawa canada
#
# 161 River Ave., Patchogue, NY
# set([]) set([]) set([])
#
#
# Bangkok, Thailand
# set([u'bangkok']) set([u'thailand']) set([u'thailand'])
# bangkok thailand
#
# Egypt
# set([]) set([u'egypt']) set([])
#  egypt
#
# Asia
# set([u'asia']) set([]) set([u'philippines'])
# asia philippines
#
# São Paulo
# set([u's\xe3o paulo']) set([]) set([u'brazil'])
# são paulo brazil
#
# 日本 神奈
# set([]) set([u'japan']) set([])
#  japan
#
# Marbella, Spain
# set([u'marbella']) set([u'spain']) set([u'spain'])
# marbella spain
#
# Chicago, IL
# set([u'chicago']) set([]) set([u'united states'])
# chicago united states
#
# Rawamangun, East Jakarta
# set([u'jakarta']) set([]) set([u'indonesia'])
# jakarta indonesia
#
# México
# set([]) set([u'mexico']) set([])
#  mexico
#
# Bangalore
# set([]) set([]) set([])
#
#
# 世田谷区
# set([]) set([]) set([])
#
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# Poitiers
# set([u'poitiers']) set([]) set([u'france'])
# poitiers france
#
# Oakland, CA
# set([u'oakland']) set([]) set([u'united states'])
# oakland united states
#
# Belfast, Northern Ireland
# set([u'belfast']) set([u'ireland']) set([u'united kingdom'])
# belfast ireland
#
# Rotterdam Area, Netherlands
# set([u'rotterdam']) set([u'netherlands']) set([u'netherlands'])
# rotterdam netherlands
#
# Hyderabad & Dubai
# set([u'hyderabad', u'dubai']) set([]) set([u'united arab emirates', u'india'])
#
#
# City of London, London
# set([u'london', u'city of london']) set([]) set([u'united kingdom'])
#  united kingdom
#
# Youngstown OH
# set([u'youngstown']) set([]) set([u'united states'])
# youngstown united states
#
# Santa Cruz, CA
# set([]) set([]) set([])
#
#
# Portland, Maine
# set([u'portland']) set([]) set([u'united states'])
# portland united states
#
# Cleveland, OH
# set([u'cleveland']) set([]) set([u'united states'])
# cleveland united states
#
# Boschi Sant'Anna, Veneto
# set([]) set([]) set([])
#
#
# 137 Waterkant St, Cape Town
# set([u'cape town']) set([]) set([u'south africa'])
# cape town south africa
#
# Solihull, England
# set([u'solihull']) set([u'united kingdom']) set([u'united kingdom'])
# solihull united kingdom
#
# Antequera, España
# set([u'antequera']) set([u'spain']) set([u'spain'])
# antequera spain
#
# Grants Pass, OR
# set([u'grants pass']) set([]) set([u'united states'])
# grants pass united states
#
# Bekasi
# set([u'bekasi']) set([]) set([u'indonesia'])
# bekasi indonesia
#
# India
# set([]) set([u'india']) set([])
#  india
#
# Venezuela. Caracas
# set([u'venezuela', u'caracas']) set([u'venezuela']) set([u'venezuela', u'cuba'])
#
#
# San Mateo, CA
# set([u'san mateo']) set([]) set([u'philippines'])
# san mateo philippines
#
# Inglaterra, Reino Unido,
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# 無料でいいから34歳の童貞貰ってくれる可愛い女の子募集中
# set([]) set([]) set([])
#
#
# Philadelphia, PA
# set([u'philadelphia']) set([]) set([u'united states'])
# philadelphia united states
#
# Online ~ Worldwide
# set([]) set([]) set([])
#
#
# Discovering new flavors
# set([]) set([]) set([])
#
#
# Dublin City, Ireland
# set([u'dublin']) set([u'ireland']) set([u'ireland'])
# dublin ireland
#
# Greenville NC
# set([u'greenville']) set([]) set([u'united states'])
# greenville united states
#
# Cardiff, South Wales, UK
# set([u'cardiff']) set([u'united kingdom']) set([u'united kingdom'])
# cardiff united kingdom
#
# Italia
# set([]) set([u'italy']) set([])
#  italy
#
# Uk
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Reigate, Redhill and Cheam
# set([u'reigate', u'redhill']) set([]) set([u'united kingdom'])
#  united kingdom
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Anderson
# set([u'anderson']) set([]) set([u'united states'])
# anderson united states
#
# London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# SANTIAGO,STI, REP. DOM.
# set([u'santiago']) set([u'dominica']) set([u'chile'])
# santiago dominica
#
# Abercrombie
# set([]) set([]) set([])
#
#
# Ocean Township, NJ
# set([]) set([]) set([])
#
#
# iPhone: 51.512405,-0.150595
# set([]) set([]) set([])
#
#
# Enriching Lives, South Africa
# set([]) set([u'south africa']) set([])
#  south africa
#
# New Jersey, USA
# set([]) set([u'united states']) set([])
#  united states
#
# 219 High Road, E18 2PB
# set([]) set([]) set([])
#
#
# Hamburg, Deutschland
# set([u'hamburg']) set([u'germany']) set([u'germany'])
# hamburg germany
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# New York City
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Old Saybrook, CT
# set([]) set([]) set([])
#
#
# Birmingham, UK
# set([u'birmingham']) set([u'united kingdom']) set([u'united kingdom'])
# birmingham united kingdom
#
# Nabiganj , Habiganj , Sylhet , Dhaka , Bangladesh
# set([u'dhaka', u'sylhet', u'habiganj']) set([u'bangladesh']) set([u'bangladesh'])
#  bangladesh
#
# Groningen, The Netherlands
# set([u'groningen']) set([u'netherlands']) set([u'netherlands'])
# groningen netherlands
#
# Indianapolis, IN Colt's Nation
# set([u'indianapolis']) set([]) set([u'united states'])
# indianapolis united states
#
# Paris
# set([u'paris']) set([]) set([u'france'])
# paris france
#
# 日本
# set([]) set([u'japan']) set([])
#  japan
#
# Where Ever You Go I Will Be!
# set([]) set([]) set([])
#
#
# Making My Dreams Reality
# set([]) set([]) set([])
#
#
# 6392 Linden Road Rockford, IL
# set([u'linden', u'rockford']) set([]) set([u'united states', u'guyana'])
#
#
# Miami Shores, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# Northern Ireland
# set([]) set([u'ireland']) set([])
#  ireland
#
# Grand Rapids, MI
# set([u'grand rapids']) set([]) set([u'united states'])
# grand rapids united states
#
# Washington, D.C.
# set([u'washington']) set([]) set([u'united kingdom'])
# washington united kingdom
#
# Kolkata
# set([u'kolkata']) set([]) set([u'india'])
# kolkata india
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Kyrgyzstan
# set([]) set([u'kyrgyzstan']) set([])
#  kyrgyzstan
#
# Tuxtla Gutiérrez, Chiapas. Mex
# set([u'tuxtla']) set([]) set([u'mexico'])
# tuxtla mexico
#
# Hot Springs, Ar
# set([u'hot springs']) set([]) set([u'united states'])
# hot springs united states
#
# New York
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Discovering new flavors
# set([]) set([]) set([])
#
#
# チーム大地
# set([]) set([]) set([])
#
#
# Alabama
# set([]) set([]) set([])
#
#
# NY
# set([]) set([]) set([])
#
#
# Fischeln, Krefeld
# set([u'krefeld']) set([]) set([u'germany'])
# krefeld germany
#
# Wien, Österreich
# set([]) set([u'austria']) set([])
#  austria
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Milky Way
# set([]) set([]) set([])
#
#
# Boston, MA
# set([u'boston']) set([]) set([u'united states'])
# boston united states
#
# Ai
# set([]) set([]) set([])
#
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Paloise exilée à Paris
# set([u'paris']) set([]) set([u'france'])
# paris france
#
# Madrid, Comunidad de Madrid
# set([u'madrid']) set([]) set([u'spain'])
# madrid spain
#
# 16 E. Patrick St  Frederick,MD
# set([u'frederick']) set([]) set([u'united states'])
# frederick united states
#
# Rancho Cucamonga, CA
# set([u'rancho cucamonga']) set([]) set([u'united states'])
# rancho cucamonga united states
#
# Jeddah
# set([u'jeddah']) set([]) set([u'saudi arabia'])
# jeddah saudi arabia
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# ❧ khz.ami ❦
# set([u'ami']) set([]) set([u'japan'])
# ami japan
#
# Milky Way
# set([]) set([]) set([])
#
#
# London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# Philippines
# set([]) set([u'philippines']) set([])
#  philippines
#
# #winesphere Brazil
# set([]) set([u'brazil']) set([])
#  brazil
#
# Alexis
# set([]) set([]) set([])
#
#
# Arkansas
# set([]) set([]) set([])
#
#
# Waterloo, Sydney
# set([u'waterloo', u'sydney']) set([]) set([u'canada', u'australia'])
#
#
# Johannesburg, South Africa
# set([u'johannesburg']) set([u'south africa']) set([u'south africa'])
# johannesburg south africa
#
# Lexington, SC
# set([u'lexington']) set([]) set([u'united states'])
# lexington united states
#
# UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Denver Colorado
# set([u'colorado', u'denver']) set([]) set([u'brazil', u'united states'])
#
#
# Gurgaon, India
# set([u'gurgaon']) set([u'india']) set([u'india'])
# gurgaon india
#
# Weezyanner
# set([]) set([]) set([])
#
#
# Washington DC
# set([u'washington']) set([]) set([u'united kingdom'])
# washington united kingdom
#
# Canary Islands, Spain
# set([]) set([u'spain']) set([])
#  spain
#
# College Station, TX
# set([u'college station']) set([]) set([u'united states'])
# college station united states
#
# Leeds, England
# set([u'leeds']) set([u'united kingdom']) set([u'united kingdom'])
# leeds united kingdom
#
# Cocoa Beach, FL
# set([u'cocoa']) set([]) set([u'united states'])
# cocoa united states
#
# Bangkok, Thailand
# set([u'bangkok']) set([u'thailand']) set([u'thailand'])
# bangkok thailand
#
# Malvern, PA
# set([]) set([]) set([])
#
#
# North Wales
# set([]) set([]) set([])
#
#
# San Francisco Bay Area, CA
# set([u'san francisco']) set([]) set([u'united states'])
# san francisco united states
#
# ATLien
# set([]) set([]) set([])
#
#
# Penrose
# set([]) set([]) set([])
#
#
# Guayaquil, Ecuador
# set([u'guayaquil']) set([u'ecuador']) set([u'ecuador'])
# guayaquil ecuador
#
# gravesend kent
# set([u'gravesend', u'kent']) set([]) set([u'united kingdom', u'united states'])
#
#
# 広島～大阪～神戸
# set([]) set([]) set([])
#
#
# Jobbers Canyon, Omaha, Neb.
# set([u'omaha']) set([]) set([u'united states'])
# omaha united states
#
# Yonkers, NY
# set([u'yonkers']) set([]) set([u'united states'])
# yonkers united states
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# United Kingdom
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Milan
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# North Oxford, MA
# set([u'oxford']) set([]) set([u'united kingdom'])
# oxford united kingdom
#
# Gloucestershire
# set([]) set([]) set([])
#
#
# SUffolk County, NY
# set([u'suffolk']) set([]) set([u'united states'])
# suffolk united states
#
# Los Angeles
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Allison
# set([]) set([]) set([])
#
#
# 全国どこかのラーメン屋さんの券売機そばの席
# set([]) set([]) set([])
#
#
# Hollywood, Los Angeles
# set([u'hollywood', u'los angeles']) set([]) set([u'united states'])
#  united states
#
# USA
# set([]) set([u'united states']) set([])
#  united states
#
# ALIENS!
# set([]) set([]) set([])
#
#
# Jaguaruana
# set([u'jaguaruana']) set([]) set([u'brazil'])
# jaguaruana brazil
#
# 91
# set([]) set([]) set([])
#
#
# New South Wales, Australia
# set([]) set([u'australia']) set([])
#  australia
#
# 1 ♡ T.O.
# set([]) set([]) set([])
#
#
# Under Riri's Umbrella ☂
# set([]) set([]) set([])
#
#
# Ocala, Florida
# set([u'ocala']) set([]) set([u'united states'])
# ocala united states
#
# الرياض, المملكة العربية السعودية
# set([]) set([u'saudi arabia']) set([])
#  saudi arabia
#
# Niverville, Manitoba
# set([]) set([]) set([])
#
#
# Roma, Lazio
# set([u'rome']) set([]) set([u'italy'])
# rome italy
#
# London, UK
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Venezia, Italy
# set([]) set([u'italy']) set([])
#  italy
#
# New Jersey, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Foggia, Puglia
# set([u'foggia']) set([]) set([u'italy'])
# foggia italy
#
# dallas, texas
# set([u'dallas']) set([]) set([u'united states'])
# dallas united states
#
# Greater Sacramento & Bay Area
# set([u'sacramento']) set([]) set([u'united states'])
# sacramento united states
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# 東京都23
# set([]) set([]) set([])
#
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# Sao Paulo, Brasil
# set([]) set([u'brazil']) set([])
#  brazil
#
# Planet Earth
# set([]) set([]) set([])
#
#
# Adams
# set([]) set([]) set([])
#
#
# Kun-ei|Pen-High
# set([]) set([]) set([])
#
#
# Kansas City
# set([u'kansas city']) set([]) set([u'united states'])
# kansas city united states
#
# Michigan
# set([]) set([]) set([])
#
#
# Probably skiing
# set([]) set([]) set([])
#
#
# Attadale, Lochcarron, Scotland
# set([]) set([]) set([])
#
#
# Paris - France
# set([u'paris']) set([u'france']) set([u'france'])
# paris france
#
# Portland, OR
# set([u'portland']) set([]) set([u'united states'])
# portland united states
#
# Querétaro
# set([]) set([]) set([])
#
#
# California
# set([]) set([]) set([])
#
#
# Florence
# set([u'florence']) set([]) set([u'italy'])
# florence italy
#
# Cork City, Ireland
# set([u'cork']) set([u'ireland']) set([u'ireland'])
# cork ireland
#
# San Francisco, CA
# set([u'san francisco']) set([]) set([u'united states'])
# san francisco united states
#
# Florida
# set([]) set([]) set([])
#
#
# New York City, NY
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Italia
# set([]) set([u'italy']) set([])
#  italy
#
# Amsterdam
# set([u'amsterdam']) set([]) set([u'netherlands'])
# amsterdam netherlands
#
# Everywhere
# set([]) set([]) set([])
#
#
# Cebu City, Philippines
# set([u'cebu city']) set([u'philippines']) set([u'philippines'])
# cebu city philippines
#
# Bristol uk
# set([u'bristol']) set([u'united kingdom']) set([u'united kingdom'])
# bristol united kingdom
#
# 日本 千葉
# set([]) set([u'japan']) set([])
#  japan
#
# Dubai
# set([u'dubai']) set([]) set([u'united arab emirates'])
# dubai united arab emirates
#
# Ontario, Canada
# set([u'ontario']) set([u'canada']) set([u'united states'])
# ontario canada
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# 東京都
# set([]) set([]) set([])
#
#
# จ.ภูเก็ต, ประเทศไทย
# set([]) set([u'thailand']) set([])
#  thailand
#
# East London & Croydon
# set([u'east london', u'croydon', u'london']) set([]) set([u'united kingdom', u'south africa'])
#
#
# Derbyshire
# set([]) set([]) set([])
#
#
# Ithaca, NY
# set([u'ithaca']) set([]) set([u'united states'])
# ithaca united states
#
# Fray Bentos, Uruguay
# set([u'fray bentos']) set([u'uruguay']) set([u'uruguay'])
# fray bentos uruguay
#
# Norge
# set([]) set([u'norway']) set([])
#  norway
#
# España
# set([]) set([u'spain']) set([])
#  spain
#
# Italia
# set([]) set([u'italy']) set([])
#  italy
#
# Magyarország
# set([]) set([u'hungary']) set([])
#  hungary
#
# Al Najda St. Abu Dhabi, UAE
# set([u'abu dhabi']) set([u'united arab emirates']) set([u'united arab emirates'])
# abu dhabi united arab emirates
#
# Hollywood, Florida
# set([u'hollywood']) set([]) set([u'united states'])
# hollywood united states
#
#  Dungarvan. Co Waterford
# set([u'waterford']) set([]) set([u'united states'])
# waterford united states
#
# London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# Everett
# set([u'everett']) set([]) set([u'united states'])
# everett united states
#
# Lisboa
# set([]) set([]) set([])
#
#
# Hungary
# set([]) set([u'hungary']) set([])
#  hungary
#
# Mad Hatter Adventures
# set([]) set([]) set([])
#
#
# Inglaterra, Reino Unido,
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Debajo de tu cama 👀
# set([]) set([]) set([])
#
#
# OKINAWA
# set([u'okinawa']) set([]) set([u'japan'])
# okinawa japan
#
# NC, NY
# set([]) set([]) set([])
#
#
# Rome
# set([u'rome']) set([]) set([u'italy'])
# rome italy
#
# North Carolina
# set([u'carolina']) set([]) set([u'puerto rico'])
# carolina puerto rico
#
# Portland, OR
# set([u'portland']) set([]) set([u'united states'])
# portland united states
#
# Plymouth, England
# set([u'plymouth']) set([u'united kingdom']) set([u'united kingdom'])
# plymouth united kingdom
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Atlanta
# set([u'atlanta']) set([]) set([u'united states'])
# atlanta united states
#
# Ireland
# set([]) set([u'ireland']) set([])
#  ireland
#
# Bath
# set([u'bath']) set([]) set([u'united kingdom'])
# bath united kingdom
#
# Munich, Bavaria
# set([u'munich']) set([]) set([u'germany'])
# munich germany
#
# Dhaka, Bangladesh
# set([u'dhaka']) set([u'bangladesh']) set([u'bangladesh'])
# dhaka bangladesh
#
# Bath
# set([u'bath']) set([]) set([u'united kingdom'])
# bath united kingdom
#
# Wiesbaden
# set([u'wiesbaden']) set([]) set([u'germany'])
# wiesbaden germany
#
# New Delhi
# set([u'new delhi', u'delhi']) set([]) set([u'india'])
#  india
#
# North West, England
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Lisboa
# set([]) set([]) set([])
#
#
# New Orleans, LA
# set([u'orleans', u'new orleans']) set([]) set([u'brazil', u'united states'])
#
#
# Vancouver, British Columbia
# set([u'columbia', u'vancouver']) set([u'colombia']) set([u'united states', u'canada'])
#
#
# California, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Kingdom of Saudi Arabia
# set([]) set([u'saudi arabia']) set([])
#  saudi arabia
#
# Radcliffe On Trent, Notts
# set([u'radcliffe']) set([]) set([u'united kingdom'])
# radcliffe united kingdom
#
# Marysville, Washington
# set([u'washington', u'marysville']) set([]) set([u'united kingdom', u'united states'])
#
#
# Liverpool, UK
# set([u'liverpool']) set([u'united kingdom']) set([u'united kingdom'])
# liverpool united kingdom
#
# NJ,CEO,OWN MY COMPANY
# set([]) set([]) set([])
#
#
# Vancouver, British Columbia
# set([u'columbia', u'vancouver']) set([u'colombia']) set([u'united states', u'canada'])
#
#
# LA
# set([]) set([]) set([])
#
#
# Bogotá
# set([u'bogot\xe1']) set([]) set([u'colombia'])
# bogotá colombia
#
# Makati City,  Philippines
# set([u'makati city']) set([u'philippines']) set([u'philippines'])
# makati city philippines
#
# Chesapeake, VA
# set([u'chesapeake']) set([]) set([u'united states'])
# chesapeake united states
#
# UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Greater Florida Keys
# set([]) set([]) set([])
#
#
# 東京都 吉祥寺 無職
# set([]) set([]) set([])
#
#
# Lyon, France
# set([u'lyon']) set([u'france']) set([u'france'])
# lyon france
#
# KC MO - In Ya Way
# set([]) set([]) set([])
#
#
# 📍🌎@Foursquare: Femi Abodunde
# set([]) set([]) set([])
#
#
# Los Angeles
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# California
# set([]) set([]) set([])
#
#
# PHL  * Ask, Believe, Receive *
# set([]) set([]) set([])
#
#
# TORRELAVEGA-CANTABRIA
# set([]) set([]) set([])
#
#
# Worldwide
# set([]) set([]) set([])
#
#
# Los Angeles
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Malaysia
# set([]) set([u'malaysia']) set([])
#  malaysia
#
# 東京都杉並区高円寺南3-58-22 4.5F
# set([]) set([]) set([])
#
#
# Ventura County, CA
# set([u'ventura']) set([]) set([u'united states'])
# ventura united states
#
# UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Tokyo
# set([u'tokyo']) set([]) set([u'japan'])
# tokyo japan
#
# Jakarta Selatan, DKI Jakarta
# set([u'jakarta']) set([]) set([u'indonesia'])
# jakarta indonesia
#
# soundcloud.com/rob-rubicco
# set([]) set([]) set([])
#
#
# United Arab of Emirates ☀
# set([]) set([]) set([])
#
#
# TERNI
# set([u'terni']) set([]) set([u'italy'])
# terni italy
#
# Anaheim, CA
# set([u'anaheim']) set([]) set([u'united states'])
# anaheim united states
#
# NY
# set([]) set([]) set([])
#
#
# BEHINDYOU. #ALWAYS
# set([]) set([]) set([])
#
#
# Seattle, Washington
# set([u'seattle', u'washington']) set([]) set([u'united states', u'united kingdom'])
#
#
# Las Vegas, NV
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# USA
# set([]) set([u'united states']) set([])
#  united states
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Indianapolis, IN 46208
# set([u'indianapolis']) set([]) set([u'united states'])
# indianapolis united states
#
# nationwide
# set([]) set([]) set([])
#
#
# grayground
# set([]) set([]) set([])
#
#
# Carnuntum, Austria
# set([]) set([u'austria']) set([])
#  austria
#
# Toronto, Ontario
# set([u'toronto', u'ontario']) set([]) set([u'canada', u'united states'])
#
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# 정국에게 인생베팅
# set([]) set([]) set([])
#
#
# Lafayette, Indiana
# set([u'lafayette']) set([]) set([u'united states'])
# lafayette united states
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Ercolano, Campania
# set([u'ercolano']) set([]) set([u'italy'])
# ercolano italy
#
# Mexico/Az/Ca/Pa/Nv
# set([u'mexico']) set([u'mexico']) set([u'philippines'])
# mexico mexico
#
# Online ~ Worldwide
# set([]) set([]) set([])
#
#
# steph@missmamosworld.com
# set([]) set([]) set([])
#
#
# Leicester, England
# set([u'leicester']) set([u'united kingdom']) set([u'united kingdom'])
# leicester united kingdom
#
# Blouberg Cape Town
# set([u'cape town']) set([]) set([u'south africa'])
# cape town south africa
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Bedford, MA
# set([u'bedford']) set([]) set([u'united kingdom'])
# bedford united kingdom
#
# Seattle, WA
# set([u'seattle']) set([]) set([u'united states'])
# seattle united states
#
# Aransas Pass, TX
# set([]) set([]) set([])
#
#
# Asia
# set([u'asia']) set([]) set([u'philippines'])
# asia philippines
#
# Veenendaal
# set([u'veenendaal']) set([]) set([u'netherlands'])
# veenendaal netherlands
#
# Móstoles, España
# set([u'm\xf3stoles']) set([u'spain']) set([u'spain'])
# móstoles spain
#
# Ampthill
# set([]) set([]) set([])
#
#
# Maracay, Aragua, Venezuela
# set([u'venezuela', u'maracay']) set([u'venezuela']) set([u'venezuela', u'cuba'])
#
#
# Rio de janeiro
# set([u'rio de janeiro']) set([]) set([u'brazil'])
# rio de janeiro brazil
#
# Kansas
# set([]) set([]) set([])
#
#
# Madrid, Comunidad de Madrid
# set([u'madrid']) set([]) set([u'spain'])
# madrid spain
#
# soccer field
# set([]) set([]) set([])
#
#
# Cambridge
# set([u'cambridge']) set([]) set([u'united kingdom'])
# cambridge united kingdom
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# Vancouver, BC Canada
# set([u'vancouver']) set([u'canada']) set([u'canada'])
# vancouver canada
#
# Seattle, WA
# set([u'seattle']) set([]) set([u'united states'])
# seattle united states
#
# 日本
# set([]) set([u'japan']) set([])
#  japan
#
# The 'Burgh...
# set([]) set([]) set([])
#
#
# New England
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Tokyo
# set([u'tokyo']) set([]) set([u'japan'])
# tokyo japan
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
#  Europe
# set([]) set([]) set([])
#
#
# Willow Grove, PA
# set([u'grove', u'willow grove']) set([]) set([u'united kingdom', u'united states'])
#
#
# NYC
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Yorkshire
# set([]) set([]) set([])
#
#
# World
# set([]) set([]) set([])
#
#
# New York
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Paris
# set([u'paris']) set([]) set([u'france'])
# paris france
#
# Cazenovia, NY
# set([]) set([]) set([])
#
#
# 埼玉県
# set([]) set([]) set([])
#
#
# New York, NY
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Toronto, Ontario
# set([u'toronto', u'ontario']) set([]) set([u'canada', u'united states'])
#
#
# Chicago, IL
# set([u'chicago']) set([]) set([u'united states'])
# chicago united states
#
# Universe
# set([]) set([]) set([])
#
#
# Colorado, USA
# set([u'colorado']) set([u'united states']) set([u'brazil'])
# colorado united states
#
# Edinburgh, Scotland
# set([u'edinburgh']) set([]) set([u'united kingdom'])
# edinburgh united kingdom
#
# Kingdom of Saudi Arabia
# set([]) set([u'saudi arabia']) set([])
#  saudi arabia
#
# Lille, France
# set([u'lille']) set([u'france']) set([u'france'])
# lille france
#
# 日本
# set([]) set([u'japan']) set([])
#  japan
#
# wc : wedart_97
# set([]) set([]) set([])
#
#
# jakarta
# set([u'jakarta']) set([]) set([u'indonesia'])
# jakarta indonesia
#
# Cuernavaca
# set([u'cuernavaca']) set([]) set([u'mexico'])
# cuernavaca mexico
#
# Toronto
# set([u'toronto']) set([]) set([u'canada'])
# toronto canada
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Worldwide
# set([]) set([]) set([])
#
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Midwest
# set([]) set([]) set([])
#
#
# Lyon, France
# set([u'lyon']) set([u'france']) set([u'france'])
# lyon france
#
# France
# set([]) set([u'france']) set([])
#  france
#
# 東京
# set([]) set([]) set([])
#
#
#  |★★★★|
# set([]) set([]) set([])
#
#
# Нижний Новгород
# set([]) set([]) set([])
#
#
# iPhone: 53.369098,-6.258330
# set([]) set([]) set([])
#
#
# 2980 Los Feliz Blvd, 90039
# set([]) set([]) set([])
#
#
# Mystic Falls
# set([]) set([]) set([])
#
#
# Long Island, New York
# set([u'new york city']) set([u'iceland']) set([u'united states'])
# new york city iceland
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# New York
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Michigan
# set([]) set([]) set([])
#
#
# Palermo, Sicilia
# set([u'palermo']) set([]) set([u'italy'])
# palermo italy
#
# LA,Miami,Qc,ATL get@ me!
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# Vancouver, British Columbia
# set([u'columbia', u'vancouver']) set([u'colombia']) set([u'united states', u'canada'])
#
#
# at the gym
# set([]) set([]) set([])
#
#
# Michigan
# set([]) set([]) set([])
#
#
# Dubai, United Arab Emirates
# set([u'dubai']) set([u'united arab emirates']) set([u'united arab emirates'])
# dubai united arab emirates
#
# Canadian Rockies
# set([]) set([]) set([])
#
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# Pontyberem, Wales
# set([]) set([]) set([])
#
#
# Sudbury, Ontario
# set([u'ontario', u'sudbury']) set([]) set([u'united states'])
#  united states
#
# Via Quattro Novembre 139, RM
# set([]) set([]) set([])
#
#
# Milano, Lombardia
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# 2980 Los Feliz Blvd, 90039
# set([]) set([]) set([])
#
#
# Madisonville
# set([u'madisonville']) set([]) set([u'united states'])
# madisonville united states
#
# US & Canada
# set([]) set([u'canada']) set([])
#  canada
#
# Essex
# set([u'essex']) set([]) set([u'united states'])
# essex united states
#
# Addison
# set([u'addison']) set([]) set([u'united states'])
# addison united states
#
# Mumbai
# set([u'mumbai']) set([]) set([u'india'])
# mumbai india
#
# Miami Beach, FL
# set([u'miami', u'miami beach']) set([]) set([u'united states'])
#  united states
#
# Oaxaca
# set([u'oaxaca']) set([]) set([u'mexico'])
# oaxaca mexico
#
# Milano -Italy-
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Miami Lakes
# set([u'miami', u'miami lakes']) set([]) set([u'united states'])
#  united states
#
# Melaka and Selangor, Malaysia
# set([]) set([u'malaysia']) set([])
#  malaysia
#
# Roseville, MI
# set([u'roseville']) set([]) set([u'united states'])
# roseville united states
#
# Boston
# set([u'boston']) set([]) set([u'united states'])
# boston united states
#
# Cambridge, England
# set([u'cambridge']) set([u'united kingdom']) set([u'united kingdom'])
# cambridge united kingdom
#
# New York
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Aylesbury, UK
# set([u'aylesbury']) set([u'united kingdom']) set([u'united kingdom'])
# aylesbury united kingdom
#
# New Jersey, USA
# set([]) set([u'united states']) set([])
#  united states
#
# USA - ITALY
# set([]) set([u'united states', u'italy']) set([])
#
#
# Kailua, Hawaii
# set([u'kailua']) set([]) set([u'united states'])
# kailua united states
#
# Barcelona, España
# set([u'barcelona']) set([u'spain']) set([u'spain'])
# barcelona spain
#
# 東京 吉祥寺
# set([]) set([]) set([])
#
#
# Graz, Österreich
# set([u'graz']) set([u'austria']) set([u'austria'])
# graz austria
#
# Θεσσαλονίκη, Ελλάς
# set([]) set([u'greece']) set([])
#  greece
#
# North Korea
# set([]) set([u'north korea', u'south korea']) set([])
#
#
# wherever the foods at
# set([]) set([]) set([])
#
#
# Makati City
# set([u'makati city']) set([]) set([u'philippines'])
# makati city philippines
#
# Tempe, AZ
# set([u'tempe']) set([]) set([u'united states'])
# tempe united states
#
# 浅草
# set([]) set([]) set([])
#
#
# Baile Àtha Cliath
# set([]) set([]) set([])
#
#
# Thailand
# set([]) set([u'thailand']) set([])
#  thailand
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Norfolk, UK
# set([u'norfolk']) set([u'norfolk island', u'united kingdom']) set([u'united states'])
#
#
# 820 Ocean Drive, Miami Beach
# set([u'miami', u'miami beach']) set([]) set([u'united states'])
#  united states
#
# nagoya
# set([u'nagoya']) set([]) set([u'japan'])
# nagoya japan
#
# Attalla
# set([]) set([]) set([])
#
#
# Medford, MA
# set([u'medford']) set([]) set([u'united states'])
# medford united states
#
# So Cal
# set([]) set([]) set([])
#
#
# 164cm/59.9kg/23.5%/age:51
# set([]) set([]) set([])
#
#
# Italy
# set([]) set([u'italy']) set([])
#  italy
#
# الرياض
# set([]) set([]) set([])
#
#
# Canton, MI
# set([u'canton']) set([]) set([u'united states'])
# canton united states
#
# Manager at Hawkshead Relish
# set([]) set([]) set([])
#
#
# Hollywood, FL
# set([u'hollywood']) set([]) set([u'united states'])
# hollywood united states
#
# San Jose, CA
# set([u'san jose']) set([]) set([u'united states'])
# san jose united states
#
# Brighton, England
# set([u'brighton']) set([u'united kingdom']) set([u'united kingdom'])
# brighton united kingdom
#
# order/delivery FuelFood Book⬇️
# set([]) set([]) set([])
#
#
# Rada Tilly- Chubut- Argentina
# set([]) set([u'argentina']) set([])
#  argentina
#
# Living with @kyroskoh (SG)
# set([]) set([]) set([])
#
#
# 601 Mission Bay Blvd North SF
# set([u'mission']) set([]) set([u'united states'])
# mission united states
#
# Comunidad Valenciana, España
# set([]) set([u'spain']) set([])
#  spain
#
# China_wuhan
# set([]) set([]) set([])
#
#
# Gloucestershire
# set([]) set([]) set([])
#
#
# Ocala, Florida
# set([u'ocala']) set([]) set([u'united states'])
# ocala united states
#
# 広島 ☞ 横浜
# set([]) set([]) set([])
#
#
# Los Angeles, California
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Mooloolaba, Australia
# set([]) set([u'australia']) set([])
#  australia
#
# Delray Beach, FL
# set([u'delray beach']) set([]) set([u'united states'])
# delray beach united states
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Manila,Philippines
# set([u'manila']) set([u'philippines']) set([u'philippines'])
# manila philippines
#
# こりん星
# set([]) set([]) set([])
#
#
# Nueva York, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Las Vegas, NV
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# Southeastern US
# set([]) set([]) set([])
#
#
# Canada
# set([]) set([u'canada']) set([])
#  canada
#
# Scotland & Andalucia
# set([]) set([]) set([])
#
#
# 351 Moreland Ave | Atlanta, GA
# set([u'atlanta']) set([]) set([u'united states'])
# atlanta united states
#
# Тольятти
# set([]) set([]) set([])
#
#
# Louisa, Virginia
# set([u'virginia']) set([]) set([u'south africa'])
# virginia south africa
#
# Нижний Новгород
# set([]) set([]) set([])
#
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Online ~ Worldwide
# set([]) set([]) set([])
#
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# RA Al Khaimah, UAE
# set([]) set([u'united arab emirates']) set([])
#  united arab emirates
#
# Raleigh, NC
# set([u'raleigh']) set([]) set([u'united states'])
# raleigh united states
#
# San Francisco, CA
# set([u'san francisco']) set([]) set([u'united states'])
# san francisco united states
#
# Ontario, Canada
# set([u'ontario']) set([u'canada']) set([u'united states'])
# ontario canada
#
# Atlantic City, NJ
# set([u'atlantic city']) set([]) set([u'united states'])
# atlantic city united states
#
# New York, NY
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# DKI Jakarta
# set([u'jakarta']) set([]) set([u'indonesia'])
# jakarta indonesia
#
# Worldwide
# set([]) set([]) set([])
#
#
# Port St Lucie, FL
# set([]) set([]) set([])
#
#
# Naperville, IL
# set([u'naperville']) set([]) set([u'united states'])
# naperville united states
#
# Haute-Vienne, Limousin
# set([]) set([]) set([])
#
#
# Wales, UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# chicago usa
# set([u'chicago']) set([u'united states']) set([u'united states'])
# chicago united states
#
# Arkham asylum
# set([]) set([]) set([])
#
#
# Lucas, Bucyrus
# set([u'lucas']) set([]) set([u'brazil'])
# lucas brazil
#
# #Worldwide
# set([]) set([]) set([])
#
#
# Indianapolis,
# set([u'indianapolis']) set([]) set([u'united states'])
# indianapolis united states
#
# Vero Beach Florida
# set([u'vero beach']) set([]) set([u'united states'])
# vero beach united states
#
# san diego
# set([u'san diego']) set([]) set([u'united states'])
# san diego united states
#
# Las Vegas, NV
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# an altered state of mind...
# set([]) set([]) set([])
#
#
# California, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Texas, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# NYC/Miami
# set([u'miami', u'new york city']) set([]) set([u'united states'])
#  united states
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# India
# set([]) set([u'india']) set([])
#  india
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Hong Kong, China
# set([u'hong kong']) set([u'china', u'hong kong']) set([u'hong kong'])
#
#
# Austin, Texas
# set([u'austin']) set([]) set([u'united states'])
# austin united states
#
# Boston, MA
# set([u'boston']) set([]) set([u'united states'])
# boston united states
#
# Altoona
# set([u'altoona']) set([]) set([u'united states'])
# altoona united states
#
# Freiburg, Schweiz
# set([u'freiburg']) set([u'switzerland']) set([u'germany'])
# freiburg switzerland
#
# Ramona, San Diego County, California
# set([u'san diego', u'ramona']) set([]) set([u'united states'])
#  united states
#
# Washington DC
# set([u'washington']) set([]) set([u'united kingdom'])
# washington united kingdom
#
# North Hollywood, Ca
# set([u'hollywood', u'north hollywood']) set([]) set([u'united states'])
#  united states
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Brentwood (Essex)
# set([u'brentwood', u'essex']) set([]) set([u'united states'])
#  united states
#
# Italia
# set([]) set([u'italy']) set([])
#  italy
#
# Adler
# set([u'adler']) set([]) set([u'russia'])
# adler russia
#
# Philippines
# set([]) set([u'philippines']) set([])
#  philippines
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Johannesburg, South Africa
# set([u'johannesburg']) set([u'south africa']) set([u'south africa'])
# johannesburg south africa
#
# England, United Kingdom
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Brynteg, Wales
# set([]) set([]) set([])
#
#
# Pisa
# set([u'pisa']) set([]) set([u'italy'])
# pisa italy
#
# Lungsod ng Maynila, Pambansang
# set([]) set([]) set([])
#
#
# Windhoek, Namibia
# set([u'windhoek']) set([u'namibia']) set([u'namibia'])
# windhoek namibia
#
# Port Alberni, British Columbia
# set([u'columbia', u'port alberni']) set([u'colombia']) set([u'united states', u'canada'])
#
#
# Milano, Lombardia
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Manchester
# set([u'manchester']) set([]) set([u'united kingdom'])
# manchester united kingdom
#
# Chile,Valparaiso, San antonio
# set([u'valparaiso', u'san antonio']) set([u'chile']) set([u'united states'])
#  chile
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# Forest, VA
# set([]) set([]) set([])
#
#
# Paris, France
# set([u'paris']) set([u'france']) set([u'france'])
# paris france
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# Mid Michigan
# set([]) set([]) set([])
#
#
# 全国どこかのラーメン屋さんの券売機そばの席
# set([]) set([]) set([])
#
#
# London/Barcelona/Worldwide
# set([u'london', u'barcelona']) set([]) set([u'united kingdom', u'spain'])
#
#
# Eunice, LA P.O. Box 524 70535
# set([]) set([]) set([])
#
#
# もっとさがさないでください
# set([]) set([]) set([])
#
#
# Asia
# set([u'asia']) set([]) set([u'philippines'])
# asia philippines
#
# Albuquerque
# set([u'albuquerque']) set([]) set([u'united states'])
# albuquerque united states
#
# 松本育で 岡山在住！スペインのハーフです！
# set([]) set([]) set([])
#
#
# Phoenix, AZ
# ...
# set([u'baguio']) set([]) set([u'philippines'])
# baguio philippines
#
# Ohio
# set([]) set([]) set([])
#
#
# Knob Noster
#
# set([]) set([]) set([])
#
#
# Argentina, CABA,
# set([]) set([u'argentina']) set([])
#  argentina
#
# Houston, TX
# set([u'houston']) set([]) set([u'united states'])
# houston united states
#
# Abernant
# set([]) set([]) set([])
#
#
# Sooke/victoria
# set([u'victoria']) set([]) set([u'canada'])
# victoria canada
#
# Italia
# set([]) set([u'italy']) set([])
#  italy
#
# Nashville, TN
# set([u'nashville']) set([]) set([u'united states'])
# nashville united states
#
# Siem Reap, Cambodia
# set([u'siem reap']) set([u'cambodia']) set([u'cambodia'])
# siem reap cambodia
#
# Italy
# set([]) set([u'italy']) set([])
#  italy
#
# Sharpsburg, Maryland
# set([]) set([]) set([])
#
#
# Abel
# set([]) set([]) set([])
#
#
# Providence, RI
# set([u'providence']) set([]) set([u'united states'])
# providence united states
#
# (South) Delhi
# set([u'delhi']) set([]) set([u'india'])
# delhi india
#
# UK
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Leeds, UK
# set([u'leeds']) set([u'united kingdom']) set([u'united kingdom'])
# leeds united kingdom
#
# Angel
# set([]) set([]) set([])
#
#
# www.seedsandchips.com
# set([]) set([]) set([])
#
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Hartsdale, NY
# set([]) set([]) set([])
#
#
# Coal Harbour & Kits, Vancouver
# set([u'vancouver']) set([]) set([u'canada'])
# vancouver canada
#
# Online ~ Worldwide
# set([]) set([]) set([])
#
#
# Jakarta
# set([u'jakarta']) set([]) set([u'indonesia'])
# jakarta indonesia
#
# Caribbean
# set([]) set([]) set([])
#
#
# Brasil
# set([]) set([u'brazil']) set([])
#  brazil
#
# Milano, Lombardia
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Kingdom of Saudi Arabia
# set([]) set([u'saudi arabia']) set([])
#  saudi arabia
#
# Phoenix
# set([u'phoenix']) set([]) set([u'united states'])
# phoenix united states
#
# Vancouver, BC
# set([u'vancouver']) set([]) set([u'canada'])
# vancouver canada
#
# Worldwide
# set([]) set([]) set([])
#
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# North Carolina, USA
# set([u'carolina']) set([u'united states']) set([u'puerto rico'])
# carolina united states
#
# Makati City
# set([u'makati city']) set([]) set([u'philippines'])
# makati city philippines
#
# England, United Kingdom
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Chi-Town but Boston bound
# set([u'boston']) set([]) set([u'united states'])
# boston united states
#
# Marseille
# set([u'marseille']) set([]) set([u'france'])
# marseille france
#
# Greenpoint, Brooklyn, NY
# set([u'brooklyn']) set([]) set([u'united states'])
# brooklyn united states
#
# Alabama
# set([]) set([]) set([])
#
#
# Pittsburgh, PA
# set([u'pittsburgh']) set([]) set([u'united states'])
# pittsburgh united states
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# South Carolina
# set([u'carolina']) set([]) set([u'puerto rico'])
# carolina puerto rico
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Tokyo Meguro
# set([u'tokyo']) set([]) set([u'japan'])
# tokyo japan
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# Miami, FL
# set([u'miami']) set([]) set([u'united states'])
# miami united states
#
# South Carolina, USA
# set([u'carolina']) set([u'united states']) set([u'puerto rico'])
# carolina united states
#
# Florida, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Ormoc City, Eastern Visayas
# set([u'ormoc']) set([]) set([u'philippines'])
# ormoc philippines
#
# Napoli, Campania
# set([]) set([]) set([])
#
#
# 東京
# set([]) set([]) set([])
#
#
# Japan
# set([]) set([u'japan']) set([])
#  japan
#
# United Kingdom
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# El Paso, TX
# set([u'el paso']) set([]) set([u'united states'])
# el paso united states
#
# Michigan • New Jersey
# set([]) set([]) set([])
#
#
# North East, England
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# North East, England
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# soundcloud.com/rob-rubicco
# set([]) set([]) set([])
#
#
# WV
# set([]) set([]) set([])
#
#
# NYC
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Beverly Hills, CA
# set([u'beverly', u'beverly hills']) set([]) set([u'united states'])
#  united states
#
# Las Vegas
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# Hayvenhurst & Neverland Ranch
# set([]) set([]) set([])
#
#
# Lagos, Nigeria
# set([u'lagos']) set([u'nigeria']) set([u'nigeria'])
# lagos nigeria
#
# Boulder, CO
# set([u'boulder']) set([]) set([u'united states'])
# boulder united states
#
# KONOHA
# set([]) set([]) set([])
#
#
# The Earth
# set([]) set([]) set([])
#
#
# New York, USA
# set([u'new york city']) set([u'united states']) set([u'united states'])
# new york city united states
#
# Chicago
# set([u'chicago']) set([]) set([u'united states'])
# chicago united states
#
# New Delhi, India
# set([u'new delhi', u'delhi']) set([u'india']) set([u'india'])
#  india
#
# anywhere but mostly AZ
# set([]) set([]) set([])
#
#
# Lagos, Nigeria
# set([u'lagos']) set([u'nigeria']) set([u'nigeria'])
# lagos nigeria
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# Bay Ridge, Brooklyn
# set([u'brooklyn']) set([]) set([u'united states'])
# brooklyn united states
#
# North of England
# set([]) set([u'united kingdom']) set([])
#  united kingdom
#
# Aalborg, Danmark
# set([u'aalborg']) set([u'denmark']) set([u'denmark'])
# aalborg denmark
#
# Berlin, Deutschland
# set([u'berlin']) set([u'germany']) set([u'germany'])
# berlin germany
#
# Discovering new flavors
# set([]) set([]) set([])
#
#
# France
# set([]) set([u'france']) set([])
#  france
#
# London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# Charlotte, NC
# set([u'charlotte']) set([]) set([u'united states'])
# charlotte united states
#
# Singapore
# set([u'singapore']) set([u'singapore']) set([u'singapore'])
# singapore singapore
#
# London,Italy,India,Europe,USA
# set([u'london']) set([u'india', u'italy', u'united states']) set([u'united kingdom'])
#
#
# Guadalajara, Jalisco
# set([u'guadalajara']) set([]) set([u'mexico'])
# guadalajara mexico
#
# Manchester, England
# set([u'manchester']) set([u'united kingdom']) set([u'united kingdom'])
# manchester united kingdom
#
# Pittsburgh, PA
# set([u'pittsburgh']) set([]) set([u'united states'])
# pittsburgh united states
#
# Milano, Lombardia
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Dublin City, Ireland
# set([u'dublin']) set([u'ireland']) set([u'ireland'])
# dublin ireland
#
# Bath
# set([u'bath']) set([]) set([u'united kingdom'])
# bath united kingdom
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# Bruxelles
# set([]) set([]) set([])
#
#
# philippines, tagum
# set([]) set([u'philippines']) set([])
#  philippines
#
# Sheffield, England
# set([u'sheffield']) set([u'united kingdom']) set([u'united kingdom'])
# sheffield united kingdom
#
# Living with @kyroskoh (SG)
# set([]) set([]) set([])
#
#
# Los Angeles, CA
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# malaysia
# set([]) set([u'malaysia']) set([])
#  malaysia
#
# Glasgow, Scotland
# set([u'glasgow']) set([]) set([u'united kingdom'])
# glasgow united kingdom
#
# Cagayan De Oro City
# set([u'cagayan de oro']) set([]) set([u'philippines'])
# cagayan de oro philippines
#
# IG: taylorleyba
# set([]) set([]) set([])
#
#
# Ontario, Canada
# set([u'ontario']) set([u'canada']) set([u'united states'])
# ontario canada
#
# Philippines
# set([]) set([u'philippines']) set([])
#  philippines
#
# Pittsburgh
# set([u'pittsburgh']) set([]) set([u'united states'])
# pittsburgh united states
#
# Alabama
# set([]) set([]) set([])
#
#
# Houston
# set([u'houston']) set([]) set([u'united states'])
# houston united states
#
# His Arms ❤️
# set([]) set([]) set([])
#
#
# London UK
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Arkansas
# set([]) set([]) set([])
#
#
# UK and Spain
# set([]) set([u'united kingdom', u'spain']) set([])
#
#
# Kota Bharu
# set([u'kota bharu', u'kota']) set([]) set([u'malaysia', u'india'])
#
#
# London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# Nantes & Tokyo
# set([u'tokyo', u'nantes']) set([]) set([u'japan', u'france'])
#
#
# Wherever there is good food!
# set([]) set([]) set([])
#
#
# Weichert, Realtors®-Team Metro
# set([u'metro']) set([]) set([u'indonesia'])
# metro indonesia
#
# Sendai JAPAN
# set([u'sendai']) set([u'japan']) set([u'japan'])
# sendai japan
#
# The World
# set([]) set([]) set([])
#
#
# WL102
# set([]) set([]) set([])
#
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# Blackburn, England
# set([u'blackburn']) set([u'united kingdom']) set([u'united kingdom'])
# blackburn united kingdom
#
# Pennsylvania, USA
# set([]) set([u'united states']) set([])
#  united states
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# CTBA/PR
# set([]) set([]) set([])
#
#
# République du Bénin
# set([]) set([u'benin']) set([])
#  benin
#
# Worldwide
# set([]) set([]) set([])
#
#
# Milano, Lombardia
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Canada
# set([]) set([u'canada']) set([])
#  canada
#
# Via Ripamonti 9, Milano
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Reno, NV
# set([u'reno']) set([]) set([u'united states'])
# reno united states
#
# Essex
# set([u'essex']) set([]) set([u'united states'])
# essex united states
#
# Direccion creativa
# set([]) set([]) set([])
#
#
# Canadian Rockies
# set([]) set([]) set([])
#
#
# TORONTO
# set([u'toronto']) set([]) set([u'canada'])
# toronto canada
#
# 747 9th Ave
# set([]) set([]) set([])
#
#
# USA - Spain
# set([]) set([u'united states', u'spain']) set([])
#
#
# Kota Kinabalu
# set([u'kota kinabalu', u'kota']) set([]) set([u'malaysia', u'india'])
#
#
# Buford, GA
# set([]) set([]) set([])
#
#
# India
# set([]) set([u'india']) set([])
#  india
#
# New York
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Nairobi
# set([u'nairobi']) set([]) set([u'kenya'])
# nairobi kenya
#
# 1621 E. 11th St. Tulsa
# set([u'tulsa']) set([]) set([u'united states'])
# tulsa united states
#
# Killingworth, CT. U.S.A.
# set([]) set([]) set([])
#
#
# Downingtown, PA
# set([]) set([]) set([])
#
#
# 愛知県小牧市
# set([]) set([]) set([])
#
#
# Νorth greece zip 64100
# set([]) set([u'greece']) set([])
#  greece
#
# India
# set([]) set([u'india']) set([])
#  india
#
# Highland, CA
# set([u'highland']) set([]) set([u'united states'])
# highland united states
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# Zurich
# set([]) set([]) set([])
#
#
# Milano
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Winter Park, FL
# set([u'winter park']) set([]) set([u'united states'])
# winter park united states
#
# Mexico, D.F.
# set([u'mexico']) set([u'mexico']) set([u'philippines'])
# mexico mexico
#
# Chicago, IL
# set([u'chicago']) set([]) set([u'united states'])
# chicago united states
#
# Earth Watching Rap Battles
# set([]) set([]) set([])
#
#
# Israel
# set([]) set([u'israel']) set([])
#  israel
#
# Altadena Woods
# set([u'altadena']) set([]) set([u'united states'])
# altadena united states
#
# Alabama, USA
# set([]) set([u'united states']) set([])
#  united states
#
# in Mogul land
# set([]) set([]) set([])
#
#
# Cambridge, England
# set([u'cambridge']) set([u'united kingdom']) set([u'united kingdom'])
# cambridge united kingdom
#
# London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# interweb
# set([]) set([]) set([])
#
#
# United States
# set([]) set([u'united states']) set([])
#  united states
#
# São Paulo / Brasil
# set([u's\xe3o paulo']) set([u'brazil']) set([u'brazil'])
# são paulo brazil
#
# BUCHAREST
# set([u'bucharest']) set([]) set([u'romania'])
# bucharest romania
#
# Toronto
# set([u'toronto']) set([]) set([u'canada'])
# toronto canada
#
# Malaysia
# set([]) set([u'malaysia']) set([])
#  malaysia
#
# Denver Colorado
# set([u'colorado', u'denver']) set([]) set([u'brazil', u'united states'])
#
#
# Medan, indonesia
# set([u'medan']) set([u'indonesia']) set([u'indonesia'])
# medan indonesia
#
# Banbury
# set([u'banbury']) set([]) set([u'united kingdom'])
# banbury united kingdom
#
# NYC
# set([u'new york city']) set([]) set([u'united states'])
# new york city united states
#
# Agricola
# set([]) set([]) set([])
#
#
# Las Vegas, NV
# set([u'las vegas']) set([]) set([u'united states'])
# las vegas united states
#
# Montbeugny, France
# set([]) set([u'france']) set([])
#  france
#
# Copenhagen, Denmark
# set([u'copenhagen']) set([u'denmark']) set([u'denmark'])
# copenhagen denmark
#
# Milano, Lombardia
# set([u'milan']) set([]) set([u'italy'])
# milan italy
#
# Córdoba, Spain
# set([u'c\xf3rdoba']) set([u'spain']) set([u'argentina'])
# córdoba spain
#
# London
# set([u'london']) set([]) set([u'united kingdom'])
# london united kingdom
#
# Hyderabad, India
# set([u'hyderabad']) set([u'india']) set([u'india'])
# hyderabad india
#
# Fiume Veneto
# set([]) set([]) set([])
#
#
# Birmingham, England
# set([u'birmingham']) set([u'united kingdom']) set([u'united kingdom'])
# birmingham united kingdom
#
# Barueri, SP, Brasil
# set([u'barueri']) set([u'brazil']) set([u'brazil'])
# barueri brazil
#
# LA
# set([]) set([]) set([])
#
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Australia
# set([]) set([u'australia']) set([])
#  australia
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# https://goo.gl/maps/PDJt2jKny6
# set([]) set([]) set([])
#
#
# Milky Way
# set([]) set([]) set([])
#
#
# Pacific Northwest
# set([]) set([]) set([])
#
#
# planet earth
# set([]) set([]) set([])
#
#
# Akron
# set([u'akron']) set([]) set([u'united states'])
# akron united states
#
# 3764 E Tremont Ave Bx, Ny
# set([]) set([]) set([])
#
#
# sydney
# set([u'sydney']) set([]) set([u'australia'])
# sydney australia
#
# Нижний Новгород
# set([]) set([]) set([])
#
#
# Moscow, Russia
# set([u'moscow']) set([u'russia']) set([u'russia'])
# moscow russia
#
# Cincinnati,OH & Palm Beach,FL
# set([u'cincinnati']) set([]) set([u'united states'])
# cincinnati united states
#
# Dubai
# set([u'dubai']) set([]) set([u'united arab emirates'])
# dubai united arab emirates
#
# Mars
# set([]) set([]) set([])
#
#
# Chapel Hill, NC
# set([u'chapel hill']) set([]) set([u'united states'])
# chapel hill united states
#
# Naga City
# set([u'naga']) set([]) set([u'philippines'])
# naga philippines
#
# Bexley, London
# set([u'london', u'bexley']) set([]) set([u'united kingdom'])
#  united kingdom
#
# Ravenna
# set([u'ravenna']) set([]) set([u'italy'])
# ravenna italy
#
# Sud-Ouest ☀️🏖️🌊🐟🦑🌶️🍇🍷🌲
# set([]) set([]) set([])
#
#
# Köln
# set([u'k\xf6ln']) set([]) set([u'germany'])
# köln germany
#
# Sheffield, England
# set([u'sheffield']) set([u'united kingdom']) set([u'united kingdom'])
# sheffield united kingdom
#
# 風の吹く場所。
# set([]) set([]) set([])
#
#
# Kitchen
# set([]) set([]) set([])
#
#
# The World
# set([]) set([]) set([])
#
#
# Liverpool/London
# set([u'liverpool', u'london']) set([]) set([u'united kingdom'])
#  united kingdom
#
# Paris france
# set([u'paris']) set([u'france']) set([u'france'])
# paris france
#
# East Anglia
# set([]) set([]) set([])
#
#
# Hawaii, USA
# set([]) set([u'united states']) set([])
#  united states
#
# Arenales 3350, Palermo. CABA
# set([u'palermo']) set([]) set([u'italy'])
# palermo italy
#
# Tokyo
# set([u'tokyo']) set([]) set([u'japan'])
# tokyo japan
#
# Vegas, USA
# set([]) set([u'united states']) set([])
#  united states
#
# california//carolina//glasgow
# set([u'glasgow', u'carolina']) set([]) set([u'united kingdom', u'puerto rico'])
#
#
# London, UK (EU Remainer)
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Mexico, DF
# set([u'mexico']) set([u'mexico']) set([u'philippines'])
# mexico mexico
#
# ＊あおもーり
# set([]) set([]) set([])
#
#
# JAPAN,KYOTO,TOKYO
# set([u'kyoto', u'tokyo']) set([u'japan']) set([u'japan'])
#  japan
#
# Los Angeles,
# set([u'los angeles']) set([]) set([u'united states'])
# los angeles united states
#
# Hellas-Verona
# set([]) set([]) set([])
#
#
# Calgary, Alberta
# set([u'calgary']) set([]) set([u'canada'])
# calgary canada
#
# London, England
# set([u'london']) set([u'united kingdom']) set([u'united kingdom'])
# london united kingdom
#
# Luxembourg
# set([u'luxembourg']) set([u'luxembourg']) set([u'luxembourg'])
# luxembourg luxembourg

# %%
print countriesIndex["uk"]
print countriesIndex["south africa"]
# Out:
# [2635167, 2635167]
# [953987, 953987, 953987]

# %% [markdown]
# # Image Classifier stats

# %%
from itertools import izip
from collections import defaultdict

true2pred=list()
true2predDict = defaultdict(list)
with open("./resources/testset.txt") as testfile, open("./resources/predicted.txt") as predfile: 
    for x, y in izip(testfile, predfile):
        x = x.strip().split("/")[0]
        y = y.strip()
        true2pred.append((x,y))
        true2predDict[x].append((x,y))

print len(true2predDict) 
print len(true2predDict["apple_pie"]), true2predDict["apple_pie"]
print len(true2pred) # 101*250
# Out:
# 101
# 250 [('apple_pie', 'baklava'), ('apple_pie', 'french_toast'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'chicken_curry'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'french_onion_soup'), ('apple_pie', 'tiramisu'), ('apple_pie', 'chocolate_cake'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'baklava'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'bread_pudding'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'pizza'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'macaroni_and_cheese'), ('apple_pie', 'apple_pie'), ('apple_pie', 'bread_pudding'), ('apple_pie', 'apple_pie'), ('apple_pie', 'french_toast'), ('apple_pie', 'apple_pie'), ('apple_pie', 'bread_pudding'), ('apple_pie', 'waffles'), ('apple_pie', 'baklava'), ('apple_pie', 'apple_pie'), ('apple_pie', 'ice_cream'), ('apple_pie', 'apple_pie'), ('apple_pie', 'cannoli'), ('apple_pie', 'bruschetta'), ('apple_pie', 'waffles'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'risotto'), ('apple_pie', 'strawberry_shortcake'), ('apple_pie', 'baklava'), ('apple_pie', 'apple_pie'), ('apple_pie', 'bread_pudding'), ('apple_pie', 'omelette'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'takoyaki'), ('apple_pie', 'beignets'), ('apple_pie', 'french_fries'), ('apple_pie', 'pizza'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'french_toast'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'guacamole'), ('apple_pie', 'apple_pie'), ('apple_pie', 'bread_pudding'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'donuts'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'lobster_bisque'), ('apple_pie', 'apple_pie'), ('apple_pie', 'baklava'), ('apple_pie', 'grilled_cheese_sandwich'), ('apple_pie', 'chocolate_mousse'), ('apple_pie', 'apple_pie'), ('apple_pie', 'ice_cream'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'baklava'), ('apple_pie', 'beignets'), ('apple_pie', 'french_toast'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'croque_madame'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'beignets'), ('apple_pie', 'omelette'), ('apple_pie', 'waffles'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'onion_rings'), ('apple_pie', 'apple_pie'), ('apple_pie', 'poutine'), ('apple_pie', 'apple_pie'), ('apple_pie', 'lasagna'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'french_toast'), ('apple_pie', 'hummus'), ('apple_pie', 'apple_pie'), ('apple_pie', 'cannoli'), ('apple_pie', 'french_toast'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'baklava'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'cheese_plate'), ('apple_pie', 'pancakes'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'french_toast'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'french_onion_soup'), ('apple_pie', 'apple_pie'), ('apple_pie', 'donuts'), ('apple_pie', 'cheese_plate'), ('apple_pie', 'apple_pie'), ('apple_pie', 'apple_pie'), ('apple_pie', 'spaghetti_bolo ...
# 25250

# %%
# precision
def recallPerClass(somelistOfTuples):
    truepos = [1 for (x,y) in somelistOfTuples if x==y]
    return len(truepos), len(somelistOfTuples), float(len(truepos)) / len(somelistOfTuples)

# %%
def precisionPerClass(className, true2pred, true2predDict):
    classInstances = true2predDict[className]
    truepos = [1 for (x,y) in classInstances if x==y]
    numPredicted = [1 for (x,y) in true2pred if y==className]
    return len(truepos), len(numPredicted), float(len(truepos)) / len(numPredicted)

# %%
recallPerClass(true2predDict["apple_pie"])
# Out:
# (144, 250, 0.576)

# %%
precisionPerClass("apple_pie", true2pred, true2predDict)
# Out:
# (144, 253, 0.5691699604743083)

# %%
import numpy as 
metricList = []
for className in true2predDict.keys():
    metricList.append(recallPerClass(true2predDict[className]))
